# %% [markdown]
# ### Python module/package imports for this chapter

# %%
import math, json, collections, itertools

# %%
import numpy as np
import matplotlib.pyplot as pp
# %matplotlib inline

# %%
from mpl_toolkits.basemap import Basemap
import geopy

# %% [markdown]
# ### Code and data needed from previous videos

# %%
medal = collections.namedtuple('medal',['year','athlete','team','event'])
medals = [medal(*line.strip().split('\t')) for line in open('goldmedals.txt','r')]

# %% [markdown]
# ## Challenge solution

# %%
medals_by_athlete = collections.Counter(medal.athlete for medal in medals)

# %%
medals_by_athlete.most_common(5)
# Out:
# [('Paavo Nurmi', 9),
#  ('Carl Lewis', 9),
#  ('Usain Bolt', 9),
#  ('Ray Ewry', 8),
#  ('Allyson Felix', 6)]

# %%
events_by_athlete_set = collections.defaultdict(set)

for medal in medals:
    events_by_athlete_set[medal.athlete].add(medal.event)

# %%
def howmany(tup):
    return len(tup[1])

sorted(events_by_athlete_set.items(),key=howmany,reverse=True)
# Out:
# [('Paavo Nurmi',
#   {'10000m men',
#    '1500m men',
#    '3000m team men',
#    '5000m men',
#    'cross country individual men',
#    'cross country team men'}),
#  ('Usain Bolt',
#   {'100m',
#    '100m men',
#    '200m',
#    '200m men',
#    '4x100m relay',
#    '4x100m relay men'}),
#  ('Ville Ritola',
#   {'10000m men',
#    '3000m steeplechase men',
#    '3000m team men',
#    '5000m men',
#    'cross country team men'}),
#  ('Allyson Felix',
#   {'200m women',
#    '4x100m relay',
#    '4x100m relay women',
#    '4x400m relay',
#    '4x400m relay women'}),
#  ('Alvin Kraenzlein',
#   {'110m hurdles men', '200m hurdles men', '60m men', 'long jump men'}),
#  ('Hannes Kolehmainen',
#   {'10000m men', '5000m men', 'cross country individual men', 'marathon men'}),
#  ('Jesse Owens',
#   {'100m men', '200m men', '4x100m relay men', 'long jump men'}),
#  ('Fanny Blankers-Koen',
#   {'100m women', '200m women', '4x100m relay women', '80m hurdles women'}),
#  ('Betty Cuthbert',
#   {'100m women', '200m women', '400m women', '4x100m relay women'}),
#  ('Carl Lewis', {'100m men', '200m men', '4x100m relay men', 'long jump men'}),
#  ('Ray Ewry',
#   {'high jump, standing men',
#    'long jump, standing men',
#    'triple jump, standing men'}),
#  ('Archie Hahn', {'100m men', '200m men', '60m men'}),
#  ('James Lightbody', {'1500m men', '3000m steeplechase men', '800m men'}),
#  ('Harry Hillman', {'200m hurdles men', '400m hurdles men', '400m men'}),
#  ('Melvin Sheppard', {'1500m men', '4x400m relay men', '800m men'}),
#  ('Emil Zatopek', {'10000m men', '5000m men', 'marathon men'}),
#  ('Harrison Dillard', {'100m men', '110m hurdles men', '4x100m relay men'}),
#  ('Robert Joseph Morrow', {'100m men', '200m men', '4x100m relay men'}),
#  ('Wilma Rudolph', {'100m women', '200m women', '4x100m relay women'}),
#  ('Irena Szewinska', {'200m women', '400m women', '4x100m relay women'}),
#  ('Renate Stecher', {'100m women', '200m women', '4x100m relay women'}),
#  ('Valerie Ann Brisco-Hooks',
#   {'200m women', '400m women', '4x400m relay women'}),
#  ('Florence Griffith-Joyner',
#   {'100m women', '200m women', '4x100m relay women'}),
#  ('Michael Johnson', {'200m men', '400m men', '4x400m relay men'}),
#  ('Tirunesh Dibaba',
#   {'10000m women', '10miles walk (16093m) women', '5000m women'}),
#  ('Thomas Burke', {'100m men', '400m men'}),
#  ('Edwin Flack', {'1500m men', '800m men'}),
#  ('Robert Garrett', {'discus throw men', 'shot put men'}),
#  ('Ellery Clark', {'high jump men', 'long jump men'}),
#  ('Charles Bennett', {'1500m men', '5000m team men'}),
#  ('Walter B. John Tewksbury', {'200m men', '400m hurdles men'}),
#  ('John Rimmer', {'4000m steeplechase men', '5000m team men'}),
#  ('Alfred Tysoe', {'5000m team men', '800m men'}),
#  ('Irving Baxter', {'high jump men', 'pole vault men'}),
#  ('Meyer Prinstein', {'long jump men', 'triple jump men'}),
#  ('Martin Sheridan', {'discus throw ancient style men', 'discus throw men'}),
#  ('Ralph Rose', {'shot put men', 'shot put, both hands men'}),
#  ('George Edward Larner', {'10miles walk (16093m) men', '3500m walk men'}),
#  ('Eric Lemming', {'javelin throw freestyle men', 'javelin throw men'}),
#  ('Ralph Craig', {'100m men', '200m men'}),
#  ('Charles Decker Reidpath', {'400m men', '4x400m relay men'}),
#  ('James Edwin Meredith', {'4x400m relay men', '800m men'}),
#  ('Jim Thorpe', {'decathlon men', 'pentathlon men'}),
#  ('Armas Rudolf Taipale',
#   {'discus throw men', 'discus throw, both hands men'}),
#  ('Patrick Mcdonald', {'56lb weight throw (25.4kg) men', 'shot put men'}),
#  ('Ugo Frigerio', {'10000m walk men', '3000m walk men'}),
#  ('Charles Paddock', {'100m men', '4x100m relay men'}),
#  ('Albert Hill', {'1500m men', '800m men'}),
#  ('Jackson Scholz', {'200m men', '4x100m relay men'}),
#  ('Harold Marion Osborn', {'decathlon men', 'high jump men'}),
#  ('Lemuel Clarence Houser', {'discus throw men', 'shot put men'}),
#  ('Percy Williams', {'100m men', '200m men'}),
#  ('Elizabeth Robinson', {'100m women', '4x100m relay women'}),
#  ('Raymond James Barbuti', {'400m men', '4x400m relay men'}),
#  ('Eddie Tolan', {'100m men', '200m men'}),
#  ('William Arthur Carr', {'400m men', '4x400m relay men'}),
#  ('Mildred Didrikson', {'80m hurdles women', 'javelin throw women'}),
#  ('Helen Herring Stephens', {'100m women', '4x100m relay women'}),
#  ('Melvin Emery Patton', {'200m men', '4x100m relay men'}),
#  ('Arthur Wint', {'400m men', '4x400m relay men'}),
#  ('Roy Braxton Cochran', {'400m hurdles men', '4x400m relay men'}),
#  ('Malvin Groston Whitfield', {'4x400m relay men', '800m men'}),
#  ('Micheline Ostermeyer', {'discus throw women', 'shot put women'}),
#  ('Lindy Remigino', {'100m men', '4x100m relay men'}),
#  ('Marjorie Jackson', {'100m women', '200m women'}),
#  ('Andrew William Stanfield', {'200m men', '4x100m relay men'}),
#  ('Vincent George Rhoden', {'400m men', '4x400m relay men'}),
#  ('Shirley Strickland-De La Hunty',
#   {'4x100m relay women', '80m hurdles women'}),
#  ('Vladimir Kuts', {'10000m men', '5000m men'}),
#  ('Charles Lamont Jenkins', {'400m men', '4x400m relay men'}),
#  ('Glenn Ashby Davis', {'400m hurdles men', '4x400m relay men'}),
#  ('Thomas William Courtney', {'4x400m relay men', '800m men'}),
#  ('Armin Hary', {'100m men', '4x100m relay men'}),
#  ('Otis Crandall Davis', {'400m men', '4x400m relay men'}),
#  ('Peter Snell', {'1500m men', '800m men'}),
#  ('Iryna Press', {'80m hurdles women', 'pentathlon women'}),
#  ('Tamara Press', {'discus throw women', 'shot put women'}),
#  ('Robert Hayes', {'100m men', '4x100m relay men'}),
#  ('Wyomia Tyus', {'100m women', '4x100m relay women'}),
#  ('Henry Carr', {'200m men', '4x400m relay men'}),
#  ('Michael Denny Larrabee', {'400m men', '4x400m relay men'}),
#  ('James Ray Hines', {'100m men', '4x100m relay men'}),
#  ('Kipchoge Keino', {'1500m men', '3000m steeplechase men'}),
#  ('Lee Edward Evans', {'400m men', '4x400m relay men'}),
#  ('Vincent Edward Matthews', {'400m men', '4x400m relay men'}),
#  ('Ingrid Becker-Mickler', {'4x100m relay women', 'pentathlon women'}),
#  ('Lasse Viren', {'10000m men', '5000m men'}),
#  ('Valery Borzov', {'100m men', '200m men'}),
#  ('Monika Zehrt', {'400m women', '4x400m relay women'}),
#  ('Annegret Richter-Irrgang', {'100m women', '4x100m relay women'}),
#  ('Heidemarie Rosendahl', {'4x100m relay women', 'long jump women'}),
#  ('Tatiana Kazankina', {'1500m women', '800m women'}),
#  ('Bärbel Eckert-Wöckel', {'200m women', '4x100m relay women'}),
#  ('Alberto Juantorena', {'400m men', '800m men'}),
#  ('Miruts Yifter', {'10000m men', '5000m men'}),
#  ('Viktor Markin', {'400m men', '4x400m relay men'}),
#  ('Evelyn Ashford', {'100m women', '4x100m relay women'}),
#  ('Alonzo C. Babers', {'400m men', '4x400m relay men'}),
#  ('Chandra Danette Cheeseborough',
#   {'4x100m relay women', '4x400m relay women'}),
#  ('Steve Lewis', {'400m men', '4x400m relay men'}),
#  ('Olga Bryzgina', {'400m women', '4x400m relay women'}),
#  ('Jackie Joyner-Kersee', {'heptathlon women', 'long jump women'}),
#  ('Gail Devers', {'100m women', '4x100m relay women'}),
#  ('Michael Marsh', {'200m men', '4x100m relay men'}),
#  ('Gwen Torrence', {'200m women', '4x100m relay women'}),
#  ('Quincy Watts', {'400m men', '4x400m relay men'}),
#  ('Marie-Jose Perec', {'200m women', '400m women'}),
#  ('Donovan Bailey', {'100m men', '4x100m relay men'}),
#  ('Svetlana Masterkova', {'1500m women', '800m women'}),
#  ('Robert Korzeniowski', {'20km walk men', '50km walk men'}),
#  ('Maurice Greene', {'100m men', '4x100m relay men'}),
#  ('Pauline Elaine Davis', {'200m women', '4x100m relay women'}),
#  ('Angelo Taylor', {'400m hurdles men', '4x400m relay men'}),
#  ('Kenenisa Bekele', {'10000m men', '5000m men'}),
#  ('Hicham El guerrouj', {'1500m men', '5000m men'}),
#  ('Kelly Holmes', {'1500m women', '800m women'}),
#  ('Veronica Campbell-Brown', {'200m women', '4x100m relay women'}),
#  ('Jeremy Wariner', {'400m men', '4x400m relay men'}),
#  ('Meseret Defar', {'5000m team women', '5000m women'}),
#  ('LaShawn Merritt', {'400m men', '4x400m relay men'}),
#  ('Asafa Powell', {'4x100m relay', '4x100m relay men'}),
#  ('Sanya Richards-Ross', {'400m women', '4x400m relay women'}),
#  ('Mo Farah', {'10miles walk (16093m) men', '5000m team men'}),
#  ('Yohan Blake', {'4x100m relay', '4x100m relay men'}),
#  ('David Lekuta Rudisha', {'800m', '800m men'}),
#  ('Kemar Bailey-Cole', {'4x100m relay', '4x100m relay men'}),
#  ('Alistair Brownlee',
#   {'triathlon (long jump / shot put / 100 yards)',
#    'triathlon (long jump / shot put / 100 yards) men'}),
#  ('Sandra Perkovic', {'discus throw', 'discus throw women'}),
#  ('Christian Taylor', {'triple jump', 'triple jump men'}),
#  ('Elaine Thompson', {'100m', '200m'}),
#  ('Tianna Bartoletta', {'4x100m relay', 'long jump'}),
#  ('Mohamed Farah', {'10miles walk (16093m)', '5000m team'}),
#  ('Thomas Curtis', {'110m hurdles men'}),
#  ('Spyridon Louis', {'marathon men'}),
#  ('William Welles Hoyt', {'pole vault men'}),
#  ('James Connolly', {'triple jump men'}),
#  ('Francis Jarvis', {'100m men'}),
#  ('George Orton', {'3000m steeplechase men'}),
#  ('Maxwell W.Maxey Long', {'400m men'}),
#  ('Sidney Robinson', {'5000m team men'}),
#  ('Stanley Rowley', {'5000m team men'}),
#  ('Rudolf Bauer', {'discus throw men'}),
#  ('John Jesus Flanagan', {'hammer throw men'}),
#  ('Michel Theato', {'marathon men'}),
#  ('Richard Sheldon', {'shot put men'}),
#  ('Frederick Schule', {'110m hurdles men'}),
#  ('David Curtis Munson', {'4miles team men'}),
#  ('Arthur Newton', {'4miles team men'}),
#  ('Paul Harry Pilgrim', {'4miles team men'}),
#  ('George Underwood', {'4miles team men'}),
#  ('Howard Valentine', {'4miles team men'}),
#  ('Etienne Desmarteau', {'56lb weight throw (25.4kg) men'}),
#  ('Thomas Francis Kiely', {'decathlon men'}),
#  ('Samuel Jones', {'high jump men'}),
#  ('Thomas Hicks', {'marathon men'}),
#  ('Charles Dvorak', {'pole vault men'}),
#  ('Max Emmerich', {'triathlon (long jump / shot put / 100 yards) men'}),
#  ('Reginald Walker', {'100m men'}),
#  ('Forrest Smithson', {'110m hurdles men'}),
#  ('Robert Kerr', {'200m men'}),
#  ('Arthur Russell', {'3200m steeplechase men'}),
#  ('William Coales', {'3miles team (4828m) men'}),
#  ('Joseph Edmund Deakin', {'3miles team (4828m) men'}),
#  ('Arthur James Robertson', {'3miles team (4828m) men'}),
#  ('Wyndham Halswelle', {'400m men'}),
#  ('Charles Joseph Bacon', {'400m hurdles men'}),
#  ('John Nathaniel Cartmell', {'4x400m relay men'}),
#  ('William Frank Hamilton', {'4x400m relay men'}),
#  ('John Baxter Taylor', {'4x400m relay men'}),
#  ('Emil Robert Voigt', {'5 miles (8047m) men'}),
#  ('Harry Franklin Porter', {'high jump men'}),
#  ('Francis C. Irons', {'long jump men'}),
#  ('John Joseph Hayes', {'marathon men'}),
#  ('Edward Tiffin Cooke', {'pole vault men'}),
#  ('Alfred Carleten Gilbert', {'pole vault men'}),
#  ('Timoty J. Ahearne', {'triple jump men'}),
#  ('George Goulding', {'10000m walk men'}),
#  ('Frederick Kelly', {'110m hurdles men'}),
#  ('Arnold Jackson', {'1500m men'}),
#  ('Tell Schirnding Berna', {'3000m team men'}),
#  ('George V. Bonhag', {'3000m team men'}),
#  ('Abel Kiviat', {'3000m team men'}),
#  ('Henry Louis Scott', {'3000m team men'}),
#  ('Norman Taber', {'3000m team men'}),
#  ('William Applegarth', {'4x100m relay men'}),
#  ("Victor Henry Augustus D'arcy", {'4x100m relay men'}),
#  ('David Henry Jacobs', {'4x100m relay men'}),
#  ('Henry Maitland Mackintosh', {'4x100m relay men'}),
#  ('Edward F. Lindberg', {'4x400m relay men'}),
#  ('Hjalmar Andersson', {'cross country team men'}),
#  ('John Eke', {'cross country team men'}),
#  ('Josef Ternström', {'cross country team men'}),
#  ('Hugo K. Wieslander', {'decathlon men'}),
#  ('Matthew J. Mcgrath', {'hammer throw men'}),
#  ('Alma Wilfred Richards', {'high jump men'}),
#  ('Platt Adams', {'high jump, standing men'}),
#  ('Juho Julius Saaristo', {'javelin throw, both hands men'}),
#  ('Albert Lovejoy Gutterson', {'long jump men'}),
#  ('Konstantinos Tsiclitiras', {'long jump, standing men'}),
#  ('Kennedy Kane Mcarthur', {'marathon men'}),
#  ('Ferdinand Reinhardt Bie', {'pentathlon men'}),
#  ('Harry Stoddard Babcock', {'pole vault men'}),
#  ('Gustav Lindblom', {'triple jump men'}),
#  ('Earl Thomson', {'110m hurdles men'}),
#  ('Allen Woodring', {'200m men'}),
#  ('Percy Hodge', {'3000m steeplechase men'}),
#  ('Horace Hallock Brown', {'3000m team men'}),
#  ('Ivan Dresser', {'3000m team men'}),
#  ('Arlie Alfred Schardt', {'3000m team men'}),
#  ("Bevil Gordon D'Urban Rudd", {'400m men'}),
#  ('Frank Loomis', {'400m hurdles men'}),
#  ('Morris Kirksey', {'4x100m relay men'}),
#  ('Loren Murchison', {'4x100m relay men'}),
#  ('John Creyghton Ainsworth-Davis', {'4x400m relay men'}),
#  ('Guy Montagu Butler', {'4x400m relay men'}),
#  ('Cecil Richmond Griffiths', {'4x400m relay men'}),
#  ('Robert Alexander Lindsay', {'4x400m relay men'}),
#  ('Joseph Guillemot', {'5000m men'}),
#  ('Frederik Teudor Koskenniemi', {'cross country team men'}),
#  ('Heikki Liimatainen', {'cross country team men'}),
#  ('Helge Andreas Lövland', {'decathlon men'}),
#  ('Elmer Konstantin Niklander', {'discus throw men'}),
#  ('Patrick Ryan', {'hammer throw men'}),
#  ('Richmond Landon', {'high jump men'}),
#  ('Jonni Myyrä', {'javelin throw men'}),
#  ('R. William E. Petersson', {'long jump men'}),
#  ('Eero Reino Lehtonen', {'pentathlon men'}),
#  ('Frank Foss', {'pole vault men'}),
#  ('Frans Wilhelmi Pörhölä', {'shot put men'}),
#  ('Vilho Immanuel Tuulos', {'triple jump men'}),
#  ('Harold Abrahams', {'100m men'}),
#  ('Daniel Kinsey', {'110m hurdles men'}),
#  ('Elias Katz', {'3000m team men'}),
#  ('Frej Liewendhal', {'3000m team men'}),
#  ('Eino Seppälä', {'3000m team men'}),
#  ('S. Talja', {'3000m team men'}),
#  ('Eric Henry Liddell', {'400m men'}),
#  ('Frederick Morgan Taylor', {'400m hurdles men'}),
#  ('Louis Alfred Clarke', {'4x100m relay men'}),
#  ('Francis Hussey', {'4x100m relay men'}),
#  ('Jeremiah Alfred Leconey', {'4x100m relay men'}),
#  ('Commodore Cochrane', {'4x400m relay men'}),
#  ('Alan Helffrich', {'4x400m relay men'}),
#  ('J. Oliver Macdonald', {'4x400m relay men'}),
#  ('William Stephenson', {'4x400m relay men'}),
#  ('Douglas Gordon Lowe', {'800m men'}),
#  ('Eero Berg', {'cross country team men'}),
#  ('Eino Rastas', {'cross country team men'}),
#  ('Väinö Jeremias Sipilä', {'cross country team men'}),
#  ('Frederick Delmont Tootell', {'hammer throw men'}),
#  ('William De Hart Hubbard', {'long jump men'}),
#  ('Albin Oskar Stenroos', {'marathon men'}),
#  ('Lee Barnes', {'pole vault men'}),
#  ('Anthony William Winter', {'triple jump men'}),
#  ('Sidney Atkinson', {'110m hurdles men'}),
#  ('Harri Edvin Larva', {'1500m men'}),
#  ('Toivo Aarne Loukola', {'3000m steeplechase men'}),
#  ('David George Burghley', {'400m hurdles men'}),
#  ('Charles Edward Borah', {'4x100m relay men'}),
#  ('James F. Quinn', {'4x100m relay men'}),
#  ('Henry Argue Russell', {'4x100m relay men'}),
#  ('Frank Clifford Wykoff', {'4x100m relay men'}),
#  ('Myrtle Alice Cook', {'4x100m relay women'}),
#  ('Fanny Rosenfeld', {'4x100m relay women'}),
#  ('Ethel M. Smith', {'4x100m relay women'}),
#  ('Jean Thompson', {'4x100m relay women'}),
#  ('Frederick Pitt Alderman', {'4x400m relay men'}),
#  ('George Hetzel Baird', {'4x400m relay men'}),
#  ('Emerson Lane Spencer', {'4x400m relay men'}),
#  ('Karoline "Lina" Radke', {'800m women'}),
#  ('Paavo Ilmari Yrjölä', {'decathlon men'}),
#  ('Halina Konopacka', {'discus throw women'}),
#  ("Patrick O'callaghan", {'hammer throw men'}),
#  ('Robert Wade King', {'high jump men'}),
#  ('Ethel Catherwood', {'high jump women'}),
#  ('Erik H. Lundqvist', {'javelin throw men'}),
#  ('Edward Barton Hamm', {'long jump men'}),
#  ('Boughera Mohamed El Ouafi', {'marathon men'}),
#  ('Sabin William Carr', {'pole vault men'}),
#  ('John H. Kuck', {'shot put men'}),
#  ('Mikio Oda', {'triple jump men'}),
#  ('Janusz Kusocinski', {'10000m men'}),
#  ('Stanislawa Walasiewicz', {'100m women'}),
#  ('George J. Jr. Saling', {'110m hurdles men'}),
#  ('Luigi Beccali', {'1500m men'}),
#  ('Volmari Iso-Hollo', {'3000m steeplechase men'}),
#  ('Robert Morton Newburgh Tisdall', {'400m hurdles men'}),
#  ('Hector Monroe Dyer', {'4x100m relay men'}),
#  ('Robert Allan Kiesel', {'4x100m relay men'}),
#  ('Martin Emmett Toppino', {'4x100m relay men'}),
#  ('Mary Louise Carew', {'4x100m relay women'}),
#  ('Evelyn Furtsch', {'4x100m relay women'}),
#  ('Annette Joan Rogers', {'4x100m relay women'}),
#  ('Wilhelmina Von bremen', {'4x100m relay women'}),
#  ('Edgar Allen Ablowich', {'4x400m relay men'}),
#  ('Ivan William Fuqua', {'4x400m relay men'}),
#  ('Karl De Witt Warner', {'4x400m relay men'}),
#  ('Lauri Aleksanteri Lehtinen', {'5000m men'}),
#  ('Thomas William Green', {'50km walk men'}),
#  ('Thomas Hampson', {'800m men'}),
#  ('James Aloysius Bernard Bausch', {'decathlon men'}),
#  ('John Franklin Anderson', {'discus throw men'}),
#  ('Lillian Copeland', {'discus throw women'}),
#  ('Duncan Mcnaughton', {'high jump men'}),
#  ('Jean Shiley', {'high jump women'}),
#  ('Matti Henrik Jarvinen', {'javelin throw men'}),
#  ('Edward Lansing Gordon', {'long jump men'}),
#  ('Juan Carlos Zabala', {'marathon men'}),
#  ('William Waring Miller', {'pole vault men'}),
#  ('Leo Joseph Sexton', {'shot put men'}),
#  ('Chuhei Nambu', {'triple jump men'}),
#  ('Ilmari Salminen', {'10000m men'}),
#  ('Forrest Grady Towns', {'110m hurdles men'}),
#  ('John Lovelock', {'1500m men'}),
#  ('Archibald Franklin Williams', {'400m men'}),
#  ('Glenn Foster Hardin', {'400m hurdles men'}),
#  ('Foy Draper', {'4x100m relay men'}),
#  ('Ralph Metcalfe', {'4x100m relay men'}),
#  ('Harriett Claiborne Bland', {'4x100m relay women'}),
#  ('Arthur Godfrey Kilner Brown', {'4x400m relay men'}),
#  ('Godfrey Lionel Rampling', {'4x400m relay men'}),
#  ('William Roberts', {'4x400m relay men'}),
#  ('Frederick Ferdinand Wolff', {'4x400m relay men'}),
#  ('Gunnar Höckert', {'5000m men'}),
#  ('Hector Harold Whitlock', {'50km walk men'}),
#  ('John Youie Woodruff', {'800m men'}),
#  ('Trebisonda Valla', {'80m hurdles women'}),
#  ('Glenn Edward Morris', {'decathlon men'}),
#  ('William Kenneth Carpenter', {'discus throw men'}),
#  ('Gisela Mauermayer', {'discus throw women'}),
#  ('Karl Hein', {'hammer throw men'}),
#  ('Cornelius Cooper Johnson', {'high jump men'}),
#  ('Ibolya Csak', {'high jump women'}),
#  ('Gerhard (Gerd) Stöck', {'javelin throw men'}),
#  ('Mathilde (Tilly) Fleischer', {'javelin throw women'}),
#  ('Kitei Son', {'marathon men'}),
#  ('Earle Elmer Meadows', {'pole vault men'}),
#  ('Hans Woellke', {'shot put men'}),
#  ('Naoto Tajima', {'triple jump men'}),
#  ('John Mikaelsson', {'10000m walk men'}),
#  ('William Franklin III Porter', {'110m hurdles men'}),
#  ('Henry Eriksson', {'1500m men'}),
#  ('Tore Sjöstrand', {'3000m steeplechase men'}),
#  ('Harold Norwood Ewell', {'4x100m relay men'}),
#  ('Lorenzo Christopher Wright', {'4x100m relay men'}),
#  ('Xenia Stad-De jong', {'4x100m relay women'}),
#  ('Gerda Johanna Marie Van der kade-Koudijs', {'4x100m relay women'}),
#  ('Jeannette Josephina Maria Witziers-Timmer', {'4x100m relay women'}),
#  ('Clifford Frederick Bourland', {'4x400m relay men'}),
#  ('Arthur Harold Harnden', {'4x400m relay men'}),
#  ('Gaston Etienne Reiff', {'5000m men'}),
#  ('John Artur Ljunggren', {'50km walk men'}),
#  ('Robert Mathias', {'decathlon men'}),
#  ('Adolfo Consolini', {'discus throw men'}),
#  ('Imre Nemeth', {'hammer throw men'}),
#  ('John Winter', {'high jump men'}),
#  ('Alice Marie Coachman', {'high jump women'}),
#  ('Kaj Tapio Rautavaara', {'javelin throw men'}),
#  ('Hermine (Herma) Bauma', {'javelin throw women'}),
#  ('William Samuel Steele', {'long jump men'}),
#  ('Olga Gyarmati', {'long jump women'}),
#  ('Delfo Cabrera', {'marathon men'}),
#  ('Owen Guinn Smith', {'pole vault men'}),
#  ('Wilbur Marvin Thompson', {'shot put men'}),
#  ('Arne Ahman', {'triple jump men'}),
#  ('Joseph Barthel', {'1500m men'}),
#  ('Horace III Ashenfelter', {'3000m steeplechase men'}),
#  ('Charles Hewes Jr. Moore', {'400m hurdles men'}),
#  ('Finis Dean Smith', {'4x100m relay men'}),
#  ('Mae Heriwentha Faggs', {'4x100m relay women'}),
#  ('Catherine Hardy', {'4x100m relay women'}),
#  ('Barbara Pearl Jones', {'4x100m relay women'}),
#  ('Janet Theresa Moreau', {'4x100m relay women'}),
#  ('Leslie Laing', {'4x400m relay men'}),
#  ('Herbert Mckenley', {'4x400m relay men'}),
#  ('Giuseppe Dordoni', {'50km walk men'}),
#  ('Simeon Garland Iness', {'discus throw men'}),
#  ('Nina Romashkova-Ponomareva', {'discus throw women'}),
#  ('Jozsef Csermak', {'hammer throw men'}),
#  ('Walter Francis Davis', {'high jump men'}),
#  ('Esther Cornelia Brand', {'high jump women'}),
#  ('Cyrus C. Jr. Young', {'javelin throw men'}),
#  ('Dana Ingrova-Zatopkova', {'javelin throw women'}),
#  ('Jerome Cousins Biffle', {'long jump men'}),
#  ('Yvette Winefred Williams', {'long jump women'}),
#  ('Robert Richards', {'pole vault men'}),
#  ('William Patrick Jr. O', {'shot put men'}),
#  ('Galina Zybina', {'shot put women'}),
#  ('Adhemar Ferreira Da Silva', {'triple jump men'}),
#  ('Lee Calhoun', {'110m hurdles men'}),
#  ('Ronald Michael Delany', {'1500m men'}),
#  ('Leonid Spirin', {'20km walk men'}),
#  ('Christopher William Brasher', {'3000m steeplechase men'}),
#  ('Walter Thane Baker', {'4x100m relay men'}),
#  ('Leamon King', {'4x100m relay men'}),
#  ('Ira James Murchison', {'4x100m relay men'}),
#  ('Norma Wilson Crooker-Fleming', {'4x100m relay women'}),
#  ('Fluer Northey Mellor-Wenham', {'4x100m relay women'}),
#  ('Louis Woodard III Jones', {'4x400m relay men'}),
#  ('Jesse William Mashburn', {'4x400m relay men'}),
#  ('Norman Richard Read', {'50km walk men'}),
#  ('Milton Gray Campbell', {'decathlon men'}),
#  ('Alfred Oerter', {'discus throw men'}),
#  ('Olga Fikotova-Connolly', {'discus throw women'}),
#  ('Harold Vincent Connolly', {'hammer throw men'}),
#  ('Charles Everett Dumas', {'high jump men'}),
#  ('Mildred Louise Mcdaniel', {'high jump women'}),
#  ('Egil Danielsen', {'javelin throw men'}),
#  ('Inese Yaunzeme', {'javelin throw women'}),
#  ('Gregory Curtis Bell', {'long jump men'}),
#  ('Elzbieta Dunska-Krzesinska', {'long jump women'}),
#  ('Alain Mimoun', {'marathon men'}),
#  ('Tamara Tyshkevich', {'shot put women'}),
#  ('Pyotr Bolotnikov', {'10000m men'}),
#  ('Herbert Elliott', {'1500m men'}),
#  ('Livio Berruti', {'200m men'}),
#  ('Vladimir Golubnichy', {'20km walk men'}),
#  ('Zdzislaw Krzyszkowiak', {'3000m steeplechase men'}),
#  ('Bernd Cullmann', {'4x100m relay men'}),
#  ('Martin Lauer', {'4x100m relay men'}),
#  ('Walter Mahlendorf', {'4x100m relay men'}),
#  ('Martha B. Hudson', {'4x100m relay women'}),
#  ('Lucinda Williams', {'4x100m relay women'}),
#  ('John Lloyd Yerman', {'4x400m relay men'}),
#  ('Earl Verdelle Young', {'4x400m relay men'}),
#  ('Murray Gordon Halberg', {'5000m men'}),
#  ('Donald James Thompson', {'50km walk men'}),
#  ('Lyudmila Lisenko-Shevtsova', {'800m women'}),
#  ('Rafer Lewis Johnson', {'decathlon men'}),
#  ('Vasili Rudenkov', {'hammer throw men'}),
#  ('Robert Shavlakadze', {'high jump men'}),
#  ('Iolanda Balas', {'high jump women'}),
#  ('Viktor Tsybulenko', {'javelin throw men'}),
#  ('Elvira Ozolina', {'javelin throw women'}),
#  ('Ralph Harold Boston', {'long jump men'}),
#  ('Vera Kolashnikova-Krepkina', {'long jump women'}),
#  ('Abebe Bikila', {'marathon men'}),
#  ('Donald George Bragg', {'pole vault men'}),
#  ('William Henry Nieder', {'shot put men'}),
#  ('Jozef Schmidt', {'triple jump men'}),
#  ('William Mills', {'10000m men'}),
#  ('Hayes Jones', {'110m hurdles men'}),
#  ('Edith Marie Mcguire', {'200m women'}),
#  ('Kenneth Joseph Matthews', {'20km walk men'}),
#  ('Gaston Roelants', {'3000m steeplechase men'}),
#  ('Warren (Rex) Jay Cawley', {'400m hurdles men'}),
#  ('Gerald Howard Ashworth', {'4x100m relay men'}),
#  ('Otis Paul Drayton', {'4x100m relay men'}),
#  ('Richard Vaughn Stebbins', {'4x100m relay men'}),
#  ('Halina Herrmann-Gorecka-Richter', {'4x100m relay women'}),
#  ('Ewa Klobukowska', {'4x100m relay women'}),
#  ('Teresa Barbara Wieczorek-Cieply', {'4x100m relay women'}),
#  ('Ollan Conley Cassell', {'4x400m relay men'}),
#  ('Ulis C. Williams', {'4x400m relay men'}),
#  ('Robert Keyser Schul', {'5000m men'}),
#  ('Abdon Pamich', {'50km walk men'}),
#  ('Ann Elizabeth Packer', {'800m women'}),
#  ('Karin Richert-Balzer', {'80m hurdles women'}),
#  ('Willi Holdorf', {'decathlon men'}),
#  ('Romuald Klim', {'hammer throw men'}),
#  ('Valeri Brumel', {'high jump men'}),
#  ('Pauli Lauri Nevala', {'javelin throw men'}),
#  ('Mihaela Penes', {'javelin throw women'}),
#  ('Lynn Davies', {'long jump men'}),
#  ('Mary Denise Bignal-Rand', {'long jump women'}),
#  ('Frederick Morgan Hansen', {'pole vault men'}),
#  ('Dallas Crutcher III Long', {'shot put men'}),
#  ('Nabiba Naftali Temu', {'10000m men'}),
#  ('Willie Davenport', {'110m hurdles men'}),
#  ('Thomas C. Smith', {'200m men'}),
#  ('Amos Kipwabok Biwott', {'3000m steeplechase men'}),
#  ('Colette Besson', {'400m women'}),
#  ('David Peter Hemery', {'400m hurdles men'}),
#  ('Charles Edward Greene', {'4x100m relay men'}),
#  ('Melvin Jr. Pender', {'4x100m relay men'}),
#  ('Ronald Ray Smith', {'4x100m relay men'}),
#  ('Margaret Johnson Bailes', {'4x100m relay women'}),
#  ('Barbara Ann Ferrell', {'4x100m relay women'}),
#  ('Mildrette Netter', {'4x100m relay women'}),
#  ('Ronald John III Freeman', {'4x400m relay men'}),
#  ('George Lawrence James', {'4x400m relay men'}),
#  ('Mohamed Gammoudi', {'5000m men'}),
#  ('Christoph Höhne', {'50km walk men'}),
#  ('Ralph Doubell', {'800m men'}),
#  ('Madeline Manning-Jackson', {'800m women'}),
#  ('Maureen Caird', {'80m hurdles women'}),
#  ('William Anthony Toomey', {'decathlon men'}),
#  ('Lia Manoliu', {'discus throw women'}),
#  ('Gyula Zsivotzky', {'hammer throw men'}),
#  ('Richard Douglas Fosbury', {'high jump men'}),
#  ('Miloslava Rezkova-Hubner', {'high jump women'}),
#  ('Yanis Lusis', {'javelin throw men'}),
#  ('Angela Nemeth-Ranky', {'javelin throw women'}),
#  ('Bob Beamon', {'long jump men'}),
#  ('Viorica Viscopoleanu', {'long jump women'}),
#  ('Mamo Wolde', {'marathon men'}),
#  ('Robert Lloyd Seagren', {'pole vault men'}),
#  ('James Randel Matson', {'shot put men'}),
#  ('Margitta Helmbold-Gummel', {'shot put women'}),
#  ('Viktor Saneev', {'triple jump men'}),
#  ('Annelie Ehrhardt', {'100m hurdles women'}),
#  ('Rodney Jr. Milburn', {'110m hurdles men'}),
#  ('Pekka Vasala', {'1500m men'}),
#  ('Lyudmila Bragina', {'1500m women'}),
#  ('Peter Frenkel', {'20km walk men'}),
#  ('John Akii-Bua', {'400m hurdles men'}),
#  ('Lawrence J. Black', {'4x100m relay men'}),
#  ('Edward James Hart', {'4x100m relay men'}),
#  ('Robert Taylor', {'4x100m relay men'}),
#  ('Gerald A. Tinker', {'4x100m relay men'}),
#  ('Christiane Krause', {'4x100m relay women'}),
#  ('Charles Asati', {'4x400m relay men'}),
#  ('Hezekiah Munyoro Nyamau', {'4x400m relay men'}),
#  ('Robert Ouko', {'4x400m relay men'}),
#  ('Julius Sang', {'4x400m relay men'}),
#  ('Dagmar Käsling', {'4x400m relay women'}),
#  ('Rita Kühne', {'4x400m relay women'}),
#  ('Helga Seidler', {'4x400m relay women'}),
#  ('Bernd Kannenberg', {'50km walk men'}),
#  ('David James Wottle', {'800m men'}),
#  ('Hildegard Falck-Janze', {'800m women'}),
#  ('Nikolai Avilov', {'decathlon men'}),
#  ('Ludvik Danek', {'discus throw men'}),
#  ('Faina Melnik', {'discus throw women'}),
#  ('Anatoli Bondarchuk', {'hammer throw men'}),
#  ('Yuri Tarmak', {'high jump men'}),
#  ('Ulrike Meyfarth', {'high jump women'}),
#  ('Klaus Wolfermann', {'javelin throw men'}),
#  ('Ruth Fuchs', {'javelin throw women'}),
#  ('Randel Luvelle Williams', {'long jump men'}),
#  ('Frank Charles Shorter', {'marathon men'}),
#  ('Mary Peters', {'pentathlon women'}),
#  ('Wolfgang Nordwig', {'pole vault men'}),
#  ('Wladyslaw Komar', {'shot put men'}),
#  ('Nadezhda Chizhova', {'shot put women'}),
#  ('Hasely Crawford', {'100m men'}),
#  ('Johanna Schaller-Klier', {'100m hurdles women'}),
#  ('Guy Drut', {'110m hurdles men'}),
#  ('John Walker', {'1500m men'}),
#  ('Donald Quarrie', {'200m men'}),
#  ('Daniel Bautista rocha', {'20km walk men'}),
#  ('Anders Garderud', {'3000m steeplechase men'}),
#  ('Edwin Moses', {'400m hurdles men'}),
#  ('Harvey Edward Glance', {'4x100m relay men'}),
#  ('Millard Frank Jr. Hampton', {'4x100m relay men'}),
#  ('John Wesley Jones', {'4x100m relay men'}),
#  ('Steven Earl Riddick', {'4x100m relay men'}),
#  ('Carla Bodendorf', {'4x100m relay women'}),
#  ('Marlies Oelsner-Göhr', {'4x100m relay women'}),
#  ('Benjamin Gene Brown', {'4x400m relay men'}),
#  ('Herman Ronald Frazier', {'4x400m relay men'}),
#  ('Frederick Vaughn Newhouse', {'4x400m relay men'}),
#  ('Maxwell Lander Parks', {'4x400m relay men'}),
#  ('Christina Brehmer-Lathan', {'4x400m relay women'}),
#  ('Doris Maletzki', {'4x400m relay women'}),
#  ('Brigitte Rohde', {'4x400m relay women'}),
#  ('Ellen Stropahl-Streidt', {'4x400m relay women'}),
#  ('William Bruce Jenner', {'decathlon men'}),
#  ('Malcolm Maurice Wilkins', {'discus throw men'}),
#  ('Evelin Schlaak-Jahl', {'discus throw women'}),
#  ('Yuri Sedykh', {'hammer throw men'}),
#  ('Jacek Wszola', {'high jump men'}),
#  ('Rosemarie Witschas-Ackermann', {'high jump women'}),
#  ('Miklos Nemeth', {'javelin throw men'}),
#  ('Arnie Robinson', {'long jump men'}),
#  ('Angela Voigt', {'long jump women'}),
#  ('Waldemar Cierpinski', {'marathon men'}),
#  ('Siegrun Siegl', {'pentathlon women'}),
#  ('Tadeusz Slusarski', {'pole vault men'}),
#  ('Udo Beyer', {'shot put men'}),
#  ('Ivanka Mikailova Christova-Todorova', {'shot put women'}),
#  ('Allan Wells', {'100m men'}),
#  ('Liudmila Kondratieva', {'100m women'}),
#  ('Vera Komisova', {'100m hurdles women'}),
#  ('Thomas Munkelt', {'110m hurdles men'}),
#  ('Sebastian Coe', {'1500m men'}),
#  ('Pietro Mennea', {'200m men'}),
#  ('Maurizio Damilano', {'20km walk men'}),
#  ('Bronislaw Malinowski', {'3000m steeplechase men'}),
#  ('Marita Koch', {'400m women'}),
#  ('Volker Beck', {'400m hurdles men'}),
#  ('Aleksandr Aksinin', {'4x100m relay men'}),
#  ('Vladimir Muravyov', {'4x100m relay men'}),
#  ('Andrei Prokofiev', {'4x100m relay men'}),
#  ('Nikolai Sidorov', {'4x100m relay men'}),
#  ('Ingrid Auerswald-Lange', {'4x100m relay women'}),
#  ('Romy Müller', {'4x100m relay women'}),
#  ('Nikolai Chernetski', {'4x400m relay men'}),
#  ('Mikhail Linge', {'4x400m relay men'}),
#  ('Remigius Valiulis', {'4x400m relay men'}),
#  ('Tatiana Goishchik', {'4x400m relay women'}),
#  ('Irina Nazarova', {'4x400m relay women'}),
#  ('Tatiana Prorochenko', {'4x400m relay women'}),
#  ('Nina Ziuskova', {'4x400m relay women'}),
#  ('Hartwig Gauder', {'50km walk men'}),
#  ('Steve Ovett', {'800m men'}),
#  ('Nadezhda Olizarenko', {'800m women'}),
#  ('Daley Thompson', {'decathlon men'}),
#  ('Viktor Rashchupkin', {'discus throw men'}),
#  ('Gerd Wessig', {'high jump men'}),
#  ('Sara Simeoni', {'high jump women'}),
#  ('Dainis Kula', {'javelin throw men'}),
#  ('Maria Colon', {'javelin throw women'}),
#  ('Lutz Dombrowski', {'long jump men'}),
#  ('Tatiana Kolpakova', {'long jump women'}),
#  ('Nadezhda Tkachenko', {'pentathlon women'}),
#  ('Wladyslaw Kozakiewicz', {'pole vault men'}),
#  ('Vladimir Kiselev', {'shot put men'}),
#  ('Ilona Schoknecht-Slupianek', {'shot put women'}),
#  ('Yaak Uudmae', {'triple jump men'}),
#  ('Alberto Cova', {'10000m men'}),
#  ('Benita Fitzgerald-Brown', {'100m hurdles women'}),
#  ('Roger Kingdom', {'110m hurdles men'}),
#  ('Gabriella Dorio', {'1500m women'}),
#  ('Ernesto Canto gudino', {'20km walk men'}),
#  ('Maricica Puica', {'3000m women'}),
#  ('Julius Korir', {'3000m steeplechase men'}),
#  ('Nawal El moutawakel', {'400m hurdles women'}),
#  ('Ronald James Brown', {'4x100m relay men'}),
#  ('Samuel Louis Graddy', {'4x100m relay men'}),
#  ('Calvin Smith', {'4x100m relay men'}),
#  ('Jeanette Bolden', {'4x100m relay women'}),
#  ('Alice Regina Brown', {'4x100m relay women'}),
#  ('Raymond Armstead', {'4x400m relay men'}),
#  ('Antonio Ricardo Mckay', {'4x400m relay men'}),
#  ('Sunder L. Nix', {'4x400m relay men'}),
#  ('Sherryl Frances Howard', {'4x400m relay women'}),
#  ('Lillie Mae Leatherwood-King', {'4x400m relay women'}),
#  ('Said Aouita', {'5000m men'}),
#  ('Raul Gonzalez', {'50km walk men'}),
#  ('Joaquim Cruz', {'800m men'}),
#  ('Doina Besliu-Melinte', {'800m women'}),
#  ('Rolf Danneberg', {'discus throw men'}),
#  ('Ria G. Stalman', {'discus throw women'}),
#  ('Juha Tiainen', {'hammer throw men'}),
#  ('Glyniss Leanne Nunn-Saunders-Cearns', {'heptathlon women'}),
#  ('Dietmar Mögenburg', {'high jump men'}),
#  ('Arto Harkonen', {'javelin throw men'}),
#  ('Teresa Sanderson', {'javelin throw women'}),
#  ('Anisoara Cusmir-Stanciu', {'long jump women'}),
#  ('Carlos Lopes', {'marathon men'}),
#  ('Joan Benoit', {'marathon women'}),
#  ('Pierre Quinon', {'pole vault men'}),
#  ('Alessandro Andrei', {'shot put men'}),
#  ('Claudia Losch', {'shot put women'}),
#  ('Alfredrick Alphonzo Joyner', {'triple jump men'}),
#  ('Moulay Brahim Boutayeb', {'10000m men'}),
#  ('Olga Bondarenko', {'10000m women'}),
#  ('Yordanka Donkova', {'100m hurdles women'}),
#  ('Peter Rono', {'1500m men'}),
#  ('Paula Ivan', {'1500m women'}),
#  ('Joseph Nathaniel Jr. Deloach', {'200m men'}),
#  ('Jozef Pribilinec', {'20km walk men'}),
#  ('Tatyana Samolenko-Dorovskikh', {'3000m women'}),
#  ('Julius Kariuki', {'3000m steeplechase men'}),
#  ('Andre Lamar Phillips', {'400m hurdles men'}),
#  ('Deborah Flintoff-King', {'400m hurdles women'}),
#  ('Viktor Bryzgin', {'4x100m relay men'}),
#  ('Vladimir Krylov', {'4x100m relay men'}),
#  ('Vitaly Savin', {'4x100m relay men'}),
#  ('Sheila Echols', {'4x100m relay women'}),
#  ('Daniel Everett', {'4x400m relay men'}),
#  ('Harry Butch . Reynolds', {'4x400m relay men'}),
#  ('Kevin Bernard Robinzine', {'4x400m relay men'}),
#  ('Tatiana Ledovskaya', {'4x400m relay women'}),
#  ('Olga Nazarova', {'4x400m relay women'}),
#  ('Mariya Pinigina', {'4x400m relay women'}),
#  ('John Ngugi', {'5000m men'}),
#  ('Vyacheslav Ivanenko', {'50km walk men'}),
#  ('Paul Ereng', {'800m men'}),
#  ('Sigrun Wodars', {'800m women'}),
#  ('Christian Schenk', {'decathlon men'}),
#  ('Jürgen Schult', {'discus throw men'}),
#  ('Martina Hellmann', {'discus throw women'}),
#  ('Sergei Litvinov', {'hammer throw men'}),
#  ('Gennadi Avdeenko', {'high jump men'}),
#  ('Dorothy Louise Ritter', {'high jump women'}),
#  ('Tapio Korjus', {'javelin throw men'}),
#  ('Petra Felke-Meier', {'javelin throw women'}),
#  ('Gelindo Bordin', {'marathon men'}),
#  ('Rosa Mota', {'marathon women'}),
#  ('Sergey Bubka', {'pole vault men'}),
#  ('Ulf Timmermann', {'shot put men'}),
#  ('Natalya Lisovskaya', {'shot put women'}),
#  ('Kristo Gantchev Markov', {'triple jump men'}),
#  ('Khalid Skah', {'10000m men'}),
#  ('Derartu Tulu', {'10000m women'}),
#  ('Yueling Chen', {'10000m walk women'}),
#  ('Linford Christie', {'100m men'}),
#  ('Paraskevi Voula Patoulidou', {'100m hurdles women'}),
#  ('Mark Mckoy', {'110m hurdles men'}),
#  ('Fermin Cacho ruiz', {'1500m men'}),
#  ('Hassiba Boulmerka', {'1500m women'}),
#  ('Daniel Plaza montero', {'20km walk men'}),
#  ('Elena Romanova', {'3000m women'}),
#  ('Mathew Birir', {'3000m steeplechase men'}),
#  ('Kevin Curtis Young', {'400m hurdles men'}),
#  ('Sally Janet Jane Gunnell', {'400m hurdles women'}),
#  ('Leroy Burrell', {'4x100m relay men'}),
#  ('James Jett', {'4x100m relay men'}),
#  ('Dennis Mitchell', {'4x100m relay men'}),
#  ('Michelle Finn', {'4x100m relay women'}),
#  ('Carlette D. Guidry-White', {'4x100m relay women'}),
#  ('Esther Jones', {'4x100m relay women'}),
#  ('Darnell Hall', {'4x400m relay men'}),
#  ('Charles L. Jenkins', {'4x400m relay men'}),
#  ('Andrew Valmon', {'4x400m relay men'}),
#  ('Marina Chmonina', {'4x400m relay women'}),
#  ('Lioudmila Djigalova', {'4x400m relay women'}),
#  ('Lilia Nurutdinova', {'4x400m relay women'}),
#  ('Yelena Rouzina', {'4x400m relay women'}),
#  ('Dieter Baumann', {'5000m men'}),
#  ('Andrey Perlov', {'50km walk men'}),
#  ('William Tanui', {'800m men'}),
#  ('Ellen Van langen', {'800m women'}),
#  ('Robert Zmelik', {'decathlon men'}),
#  ('Romas Ubartas', {'discus throw men'}),
#  ('Maritza Marten', {'discus throw women'}),
#  ('Andrey Abduvaliev', {'hammer throw men'}),
#  ('Javier Sotomayor', {'high jump men'}),
#  ('Heike Henkel', {'high jump women'}),
#  ('Jan Zelezny', {'javelin throw men'}),
#  ('Silke Renk', {'javelin throw women'}),
#  ('Heike Drechsler', {'long jump women'}),
#  ('Young-Cho Hwang', {'marathon men'}),
#  ('Valentina Yegorova', {'marathon women'}),
#  ('Maksim Tarasov', {'pole vault men'}),
#  ('Michael D. Stulce', {'shot put men'}),
#  ('Svetlana Krivelyova', {'shot put women'}),
#  ('Mike Conley', {'triple jump men'}),
#  ('Haile Gebrselassie', {'10000m men'}),
#  ('Fernanda Ribeiro', {'10000m women'}),
#  ('Yelena Nikolayeva', {'10000m walk women'}),
#  ('Ludmila Engquist', {'100m hurdles women'}),
#  ('Allen Johnson', {'110m hurdles men'}),
#  ('Nourredine Morceli', {'1500m men'}),
#  ('Jefferson Perez', {'20km walk men'}),
#  ('Joseph Keter', {'3000m steeplechase men'}),
#  ('Derrick Adkins', {'400m hurdles men'}),
#  ('Deon Marie Hemmings', {'400m hurdles women'}),
#  ('Carlton Chambers', {'4x100m relay men'}),
#  ('Robert Esmie', {'4x100m relay men'}),
#  ('Glenroy Gilbert', {'4x100m relay men'}),
#  ('Bruny Surin', {'4x100m relay men'}),
#  ('Chryste Gaines', {'4x100m relay women'}),
#  ('Inger Miller', {'4x100m relay women'}),
#  ('Alvin Harrison', {'4x400m relay men'}),
#  ('Anthuan Maybank', {'4x400m relay men'}),
#  ('Derek Mills', {'4x400m relay men'}),
#  ('Jason Rouser', {'4x400m relay men'}),
#  ('Lamont Smith', {'4x400m relay men'}),
#  ('Kim Graham', {'4x400m relay women'}),
#  ('Maicel Malone', {'4x400m relay women'}),
#  ('Jearl Miles', {'4x400m relay women'}),
#  ('Rochelle Stevens', {'4x400m relay women'}),
#  ('Linetta Wilson', {'4x400m relay women'}),
#  ('Venuste Niyongabo', {'5000m men'}),
#  ('Junxia Wang', {'5000m women'}),
#  ('Vebjorn Rodal', {'800m men'}),
#  ("Dan O'brien", {'decathlon men'}),
#  ('Lars Riedel', {'discus throw men'}),
#  ('Ilke Wyludda', {'discus throw women'}),
#  ('Balazs Kiss', {'hammer throw men'}),
#  ('Ghada Shouaa', {'heptathlon women'}),
#  ('Charles Austin', {'high jump men'}),
#  ('Stefka Kostadinova', {'high jump women'}),
#  ('Heli Orvokki Rantanen', {'javelin throw women'}),
#  ('Chioma Ajunwa', {'long jump women'}),
#  ('Josia Thugwane', {'marathon men'}),
#  ('Fatuma Roba', {'marathon women'}),
#  ('Jean Galfione', {'pole vault men'}),
#  ('Eric Randolph Barnes', {'shot put men'}),
#  ('Astrid Kumbernuss', {'shot put women'}),
#  ('Kenny Harrison', {'triple jump men'}),
#  ('Inessa Kravets', {'triple jump women'}),
#  ('Olga Shishigina', {'100m hurdles women'}),
#  ('Anier Garcia', {'110m hurdles men'}),
#  ('Noah Kiprono Ngenyi', {'1500m men'}),
#  ('Nouria Merah-Benida', {'1500m women'}),
#  ('Konstantinos Kenteris', {'200m men'}),
#  ('Liping Wang', {'20km race walk women'}),
#  ('Reuben Kosgei', {'3000m steeplechase men'}),
#  ('Cathy Freeman', {'400m women'}),
#  ('Irina Privalova', {'400m hurdles women'}),
#  ('Kenneth Brokenburr', {'4x100m relay men'}),
#  ('Jon Drummond', {'4x100m relay men'}),
#  ('Brian Lewis', {'4x100m relay men'}),
#  ('Tim Montgomery', {'4x100m relay men'}),
#  ('Bernard Williams iii', {'4x100m relay men'}),
#  ('Debbie Ferguson-Mckenzie', {'4x100m relay women'}),
#  ('Sevatheda Fynes', {'4x100m relay women'}),
#  ('Eldice Lewis', {'4x100m relay women'}),
#  ('Chandra Sturrup', {'4x100m relay women'}),
#  ('Andrea Anderson', {'4x400m relay women'}),
#  ('LaTasha Colander', {'4x400m relay women'}),
#  ('Monique Hennagan', {'4x400m relay women'}),
#  ('Millon Wolde', {'5000m men'}),
#  ('Gabriela Szabo', {'5000m women'}),
#  ('Nils Schumann', {'800m men'}),
#  ('Maria Mutola', {'800m women'}),
#  ('Erki Nool', {'decathlon men'}),
#  ('Virgilijus Alekna', {'discus throw men'}),
#  ('Ellina Zvereva', {'discus throw women'}),
#  ('Szymon Ziolkowski', {'hammer throw men'}),
#  ('Kamila Skolimowska', {'hammer throw women'}),
#  ('Denise Lewis', {'heptathlon women'}),
#  ('Sergey Kliugin', {'high jump men'}),
#  ('Yelena Yelesina', {'high jump women'}),
#  ('Trine Hattestad', {'javelin throw women'}),
#  ('Ivan Pedroso', {'long jump men'}),
#  ('Gezahegne Abera', {'marathon men'}),
#  ('Naoko Takahashi', {'marathon women'}),
#  ('Nick Hysong', {'pole vault men'}),
#  ('Stacy Dragila', {'pole vault women'}),
#  ('Arsi Harju', {'shot put men'}),
#  ('Yanina Karolchik', {'shot put women'}),
#  ('Jonathan David Edwards', {'triple jump men'}),
#  ('Tereza Marinova', {'triple jump women'}),
#  ('Huina Xing', {'10000m women'}),
#  ('Justin Gatlin', {'100m men'}),
#  ('Yuliya Nesterenko', {'100m women'}),
#  ('Joanna Hayes', {'100m hurdles women'}),
#  ('Xiang Liu', {'110m hurdles men'}),
#  ('Shawn Crawford', {'200m men'}),
#  ('Athanasia Tsoumeleka', {'20km race walk women'}),
#  ('Ivano Brugnetti', {'20km walk men'}),
#  ('Ezekiel Kemboi', {'3000m steeplechase men'}),
#  ('Tonique Williams-Darling', {'400m women'}),
#  ('Felix Sanchez', {'400m hurdles men'}),
#  ('Fani Chalkia', {'400m hurdles women'}),
#  ('Darren Campbell', {'4x100m relay men'}),
#  ('Marlon Devonish', {'4x100m relay men'}),
#  ('Jason Gardener', {'4x100m relay men'}),
#  ('Mark Lewis-Francis', {'4x100m relay men'}),
#  ('Aleen Bailey', {'4x100m relay women'}),
#  ('Tanya Lawrence', {'4x100m relay women'}),
#  ('Beverly Mcdonald', {'4x100m relay women'}),
#  ('Sherone Simpson', {'4x100m relay women'}),
#  ('Derrick Brew', {'4x400m relay men'}),
#  ('Otis Harris', {'4x400m relay men'}),
#  ('Darold Williamson', {'4x400m relay men'}),
#  ('Kelly Willie', {'4x400m relay men'}),
#  ('Crystal Cox', {'4x400m relay women'}),
#  ('Monique Henderson', {'4x400m relay women'}),
#  ('Sanya Richards', {'4x400m relay women'}),
#  ('Moushaumi Robinson', {'4x400m relay women'}),
#  ('Deedee Trotter', {'4x400m relay women'}),
#  ('Yuriy Borzakovskiy', {'800m men'}),
#  ('Roman Sebrle', {'decathlon men'}),
#  ('Natalya Sadova', {'discus throw women'}),
#  ('Koji Murofushi', {'hammer throw men'}),
#  ('Olga Kuzenkova', {'hammer throw women'}),
#  ('Carolina Kluft', {'heptathlon women'}),
#  ('Stefan Holm', {'high jump men'}),
#  ('Elena Slesarenko', {'high jump women'}),
#  ('Andreas Thorkildsen', {'javelin throw men'}),
#  ('Osleidys Menendez', {'javelin throw women'}),
#  ('Dwight Phillips', {'long jump men'}),
#  ('Tatyana Lebedeva', {'long jump women'}),
#  ('Stefano Baldini', {'marathon men'}),
#  ('Mizuki Noguchi', {'marathon women'}),
#  ('Timothy Mack', {'pole vault men'}),
#  ('Elena Isinbaeva', {'pole vault women'}),
#  ('Yuriy Bilonog', {'shot put men'}),
#  ('Yumileidi Cumba', {'shot put women'}),
#  ('Christian Olsson', {'triple jump men'}),
#  ('Francoise Mbango etone', {'triple jump women'}),
#  ('Shelly-Ann Fraser', {'100m women'}),
#  ('Dawn Harper', {'100m hurdles women'}),
#  ('Dayron Robles', {'110m hurdles men'}),
#  ('Asbel Kipruto Kiprop', {'1500m men'}),
#  ('Nancy jebet Langat', {'1500m women'}),
#  ('Olga Kaniskina', {'20km race walk women'}),
#  ('Valeriy Borchin', {'20km walk men'}),
#  ('Brimin Kiprop Kipruto', {'3000m steeplechase men'}),
#  ('Gulnara Galkina-Samitova', {'3000m steeplechase women'}),
#  ('Christine Ohuruogu', {'400m women'}),
#  ('Melaine Walker', {'400m hurdles women'}),
#  ('Nesta Carter', {'4x100m relay men'}),
#  ('Michael Frater', {'4x100m relay men'}),
#  ('Yuliya Chermoshanskaya', {'4x100m relay women'}),
#  ('Aleksandra Fedoriva', {'4x100m relay women'}),
#  ('Yulia Gushchina', {'4x100m relay women'}),
#  ('Evgeniya Polyakova', {'4x100m relay women'}),
#  ('David Neville', {'4x400m relay men'}),
#  ('Mary Wineberg', {'4x400m relay women'}),
#  ('Alex Schwazer', {'50km walk men'}),
#  ('Wilfred Bungei', {'800m men'}),
#  ('Pamela Jelimo', {'800m women'}),
#  ('Bryan Clay', {'decathlon men'}),
#  ('Gerd Kanter', {'discus throw men'}),
#  ('Stephanie Brown trafton', {'discus throw women'}),
#  ('Primoz Kozmus', {'hammer throw men'}),
#  ('Aksana Miankova', {'hammer throw women'}),
#  ('Nataliia Dobrynska', {'heptathlon women'}),
#  ('Andrey Silnov', {'high jump men'}),
#  ('Tia Hellebaut', {'high jump women'}),
#  ('Barbora Spotakova', {'javelin throw women'}),
#  ('Irving Jahir Saladino aranda', {'long jump men'}),
#  ('Maurren Higa Maggi', {'long jump women'}),
#  ('Samuel Kamau Wansiru', {'marathon men'}),
#  ('Constantina Tomescu', {'marathon women'}),
#  ('Steve Hooker', {'pole vault men'}),
#  ('Tomasz Majewski', {'shot put men'}),
#  ('Valerie Vili', {'shot put women'}),
#  ('Nelson Evora', {'triple jump men'}),
#  ('Shelly-Ann Fraser-Pryce', {'100m women'}),
#  ('Carmelita Jeter', {'4x100m relay women'}),
#  ('Natalya Antyukh', {'400m hurdles women'}),
#  ('DeeDee Trotter', {'4x400m relay women'}),
#  ('Yuliya Zaripova', {'3000m steeplechase women'}),
#  ('Ivan Ukhov', {'high jump men'}),
#  ('Anna Chicherova', {'high jump women'}),
#  ('Tatyana Lysenko', {'hammer throw women'}),
#  ('Sergey Kirdyapkin', {'50km walk men'}),
#  ('Elena Lashmanova', {'20km walk women'}),
#  ('Mariya Savinova', {'800m women'}),
#  ('Valerie Adams', {'shot put women'}),
#  ('Olga Rypakova', {'triple jump women'}),
#  ('Robert Harting', {'discus throw men'}),
#  ('Krisztian Pars', {'hammer throw men'}),
#  ('Kirani James', {'400m men'}),
#  ('Jessica Ennis', {'heptathlon'}),
#  ('Tiki Gelana', {'marathon women'}),
#  ('Greg Rutherford', {'long jump men'}),
#  ('Renaud Lavillenie', {'pole vault men'}),
#  ('Sally Pearson', {'100m hurdles women'}),
#  ('Taoufik Makhloufi', {'1500m men'}),
#  ('Ding Chen', {'20km walk men'}),
#  ('Chris Brown', {'4x400m relay men'}),
#  ('Michael Mathieu', {'4x400m relay men'}),
#  ('Ramon Miller', {'4x400m relay men'}),
#  ('Demetrius Pinder', {'4x400m relay men'}),
#  ('Lauryn Williams', {'4x100m relay women'}),
#  ('Jennifer Suhr', {'pole vault women'}),
#  ('Ashton Eaton', {'decathlon'}),
#  ('Keshia Baker', {'4x400m relay women'}),
#  ('Diamond Dixon', {'4x400m relay women'}),
#  ('Brittney Reese', {'long jump women'}),
#  ('Keshorn Walcott', {'javelin throw men'}),
#  ('Stephen Kiprotich', {'marathon men'}),
#  ('Alptekin Asli Cakir', {'1500m women'}),
#  ('Nicola Spirig', {'triathlon (long jump / shot put / 100 yards) women'}),
#  ('Bianca Knight', {'4x100m relay women'}),
#  ('Aries Merritt', {'110m hurdles men'}),
#  ('Jeneba Tarmoh', {'4x100m relay women'}),
#  ('Tianna Madison', {'4x100m relay women'}),
#  ('Francena McCorory', {'4x400m relay women'}),
#  ('Tori Bowie', {'4x100m relay'}),
#  ('Vivian Jepkemoi Cheruiyot', {'5000m team'}),
#  ('Almaz Ayana', {'10miles walk (16093m)'}),
#  ('Lashawn Merritt', {'4x400m relay'}),
#  ('Morolake Akinosun', {'4x100m relay'}),
#  ('Nickel Ashmeade', {'4x100m relay'}),
#  ('Ruth Beitia', {'high jump'}),
#  ('Michelle Carter', {'shot put'}),
#  ('Matthew Centrowitz', {'1500m'}),
#  ('Kerron Clement', {'400m hurdles'}),
#  ('Kyle Clemons', {'4x400m relay'}),
#  ('Ryan Crouser', {'shot put'}),
#  ('Thiago Braz Da Silva', {'pole vault'}),
#  ('Derek Drouin', {'high jump'}),
#  ('Taylor Ellis-Watson', {'4x400m relay'}),
#  ('Phyllis Francis', {'4x400m relay'}),
#  ('English Gardner', {'4x100m relay'}),
#  ('Arman Hall', {'4x400m relay'}),
#  ('Christoph Harting', {'discus throw'}),
#  ('Natasha Hastings', {'4x400m relay'}),
#  ('Jeff Henderson', {'long jump'}),
#  ('Caterine Ibarguen', {'triple jump'}),
#  ('Ruth Jebet', {'3000m steeplechase'}),
#  ('Gwen Jorgensen', {'triathlon (long jump / shot put / 100 yards)'}),
#  ('Eliud Kipchoge', {'marathon'}),
#  ('Conseslus Kipruto', {'3000m steeplechase'}),
#  ('Faith Chepngetich Kipyegon', {'1500m'}),
#  ('Sara Kolak', {'javelin throw'}),
#  ('Hong Liu', {'20km walk'}),
#  ('Francena Mccorory', {'4x400m relay'}),
#  ('Omar Mcleod', {'110m hurdles'}),
#  ('Tony Mcquay', {'4x400m relay'}),
#  ('Shaunae Miller', {'400m'}),
#  ('Jevaughn Minzie', {'4x100m relay'}),
#  ('Dalilah Muhammad', {'400m hurdles'}),
#  ('Dilshod Nazarov', {'hammer throw'}),
#  ('Courtney Okolo', {'4x400m relay'}),
#  ('Jenna Prandini', {'4x100m relay'}),
#  ('Gil Roberts', {'4x400m relay'}),
#  ('Thomas Rohler', {'javelin throw'}),
#  ('Brianna Rollins', {'100m hurdles'}),
#  ('Caster Semenya', {'800m'}),
#  ('Ekaterini Stefanidi', {'pole vault'}),
#  ('Jemima Jelagat Sumgong', {'marathon'}),
#  ('Nafissatou Thiam', {'heptathlon'}),
#  ('Matej Toth', {'50km walk'}),
#  ('NIEKERK Wayde Van', {'400m'}),
#  ('David Verburg', {'4x400m relay'}),
#  ('Zhen Wang', {'20km walk'}),
#  ('Ariana Washington', {'4x100m relay'}),
#  ('Anita Wlodarczyk', {'hammer throw'})]

# %%
def clean(event):
    return ' '.join(word for word in event.split() if word not in ('men','women'))

# %%
clean('100m')
# Out:
# '100m'

# %%
clean('100m men')
# Out:
# '100m'

# %%
events_by_athlete_set = collections.defaultdict(set)

for medal in medals:
    events_by_athlete_set[medal.athlete].add(clean(medal.event))

def howmany(tup):
    return len(tup[1])

sorted(events_by_athlete_set.items(),key=howmany,reverse=True)
# Out:
# [('Paavo Nurmi',
#   {'10000m',
#    '1500m',
#    '3000m team',
#    '5000m',
#    'cross country individual',
#    'cross country team'}),
#  ('Ville Ritola',
#   {'10000m',
#    '3000m steeplechase',
#    '3000m team',
#    '5000m',
#    'cross country team'}),
#  ('Alvin Kraenzlein', {'110m hurdles', '200m hurdles', '60m', 'long jump'}),
#  ('Hannes Kolehmainen',
#   {'10000m', '5000m', 'cross country individual', 'marathon'}),
#  ('Jesse Owens', {'100m', '200m', '4x100m relay', 'long jump'}),
#  ('Fanny Blankers-Koen', {'100m', '200m', '4x100m relay', '80m hurdles'}),
#  ('Betty Cuthbert', {'100m', '200m', '400m', '4x100m relay'}),
#  ('Carl Lewis', {'100m', '200m', '4x100m relay', 'long jump'}),
#  ('Ray Ewry',
#   {'high jump, standing', 'long jump, standing', 'triple jump, standing'}),
#  ('Archie Hahn', {'100m', '200m', '60m'}),
#  ('James Lightbody', {'1500m', '3000m steeplechase', '800m'}),
#  ('Harry Hillman', {'200m hurdles', '400m', '400m hurdles'}),
#  ('Melvin Sheppard', {'1500m', '4x400m relay', '800m'}),
#  ('Emil Zatopek', {'10000m', '5000m', 'marathon'}),
#  ('Harrison Dillard', {'100m', '110m hurdles', '4x100m relay'}),
#  ('Robert Joseph Morrow', {'100m', '200m', '4x100m relay'}),
#  ('Wilma Rudolph', {'100m', '200m', '4x100m relay'}),
#  ('Irena Szewinska', {'200m', '400m', '4x100m relay'}),
#  ('Renate Stecher', {'100m', '200m', '4x100m relay'}),
#  ('Valerie Ann Brisco-Hooks', {'200m', '400m', '4x400m relay'}),
#  ('Florence Griffith-Joyner', {'100m', '200m', '4x100m relay'}),
#  ('Michael Johnson', {'200m', '400m', '4x400m relay'}),
#  ('Tirunesh Dibaba', {'10000m', '10miles walk (16093m)', '5000m'}),
#  ('Usain Bolt', {'100m', '200m', '4x100m relay'}),
#  ('Allyson Felix', {'200m', '4x100m relay', '4x400m relay'}),
#  ('Thomas Burke', {'100m', '400m'}),
#  ('Edwin Flack', {'1500m', '800m'}),
#  ('Robert Garrett', {'discus throw', 'shot put'}),
#  ('Ellery Clark', {'high jump', 'long jump'}),
#  ('Charles Bennett', {'1500m', '5000m team'}),
#  ('Walter B. John Tewksbury', {'200m', '400m hurdles'}),
#  ('John Rimmer', {'4000m steeplechase', '5000m team'}),
#  ('Alfred Tysoe', {'5000m team', '800m'}),
#  ('Irving Baxter', {'high jump', 'pole vault'}),
#  ('Meyer Prinstein', {'long jump', 'triple jump'}),
#  ('Martin Sheridan', {'discus throw', 'discus throw ancient style'}),
#  ('Ralph Rose', {'shot put', 'shot put, both hands'}),
#  ('George Edward Larner', {'10miles walk (16093m)', '3500m walk'}),
#  ('Eric Lemming', {'javelin throw', 'javelin throw freestyle'}),
#  ('Ralph Craig', {'100m', '200m'}),
#  ('Charles Decker Reidpath', {'400m', '4x400m relay'}),
#  ('James Edwin Meredith', {'4x400m relay', '800m'}),
#  ('Jim Thorpe', {'decathlon', 'pentathlon'}),
#  ('Armas Rudolf Taipale', {'discus throw', 'discus throw, both hands'}),
#  ('Patrick Mcdonald', {'56lb weight throw (25.4kg)', 'shot put'}),
#  ('Ugo Frigerio', {'10000m walk', '3000m walk'}),
#  ('Charles Paddock', {'100m', '4x100m relay'}),
#  ('Albert Hill', {'1500m', '800m'}),
#  ('Jackson Scholz', {'200m', '4x100m relay'}),
#  ('Harold Marion Osborn', {'decathlon', 'high jump'}),
#  ('Lemuel Clarence Houser', {'discus throw', 'shot put'}),
#  ('Percy Williams', {'100m', '200m'}),
#  ('Elizabeth Robinson', {'100m', '4x100m relay'}),
#  ('Raymond James Barbuti', {'400m', '4x400m relay'}),
#  ('Eddie Tolan', {'100m', '200m'}),
#  ('William Arthur Carr', {'400m', '4x400m relay'}),
#  ('Mildred Didrikson', {'80m hurdles', 'javelin throw'}),
#  ('Helen Herring Stephens', {'100m', '4x100m relay'}),
#  ('Melvin Emery Patton', {'200m', '4x100m relay'}),
#  ('Arthur Wint', {'400m', '4x400m relay'}),
#  ('Roy Braxton Cochran', {'400m hurdles', '4x400m relay'}),
#  ('Malvin Groston Whitfield', {'4x400m relay', '800m'}),
#  ('Micheline Ostermeyer', {'discus throw', 'shot put'}),
#  ('Lindy Remigino', {'100m', '4x100m relay'}),
#  ('Marjorie Jackson', {'100m', '200m'}),
#  ('Andrew William Stanfield', {'200m', '4x100m relay'}),
#  ('Vincent George Rhoden', {'400m', '4x400m relay'}),
#  ('Shirley Strickland-De La Hunty', {'4x100m relay', '80m hurdles'}),
#  ('Vladimir Kuts', {'10000m', '5000m'}),
#  ('Charles Lamont Jenkins', {'400m', '4x400m relay'}),
#  ('Glenn Ashby Davis', {'400m hurdles', '4x400m relay'}),
#  ('Thomas William Courtney', {'4x400m relay', '800m'}),
#  ('Armin Hary', {'100m', '4x100m relay'}),
#  ('Otis Crandall Davis', {'400m', '4x400m relay'}),
#  ('Peter Snell', {'1500m', '800m'}),
#  ('Iryna Press', {'80m hurdles', 'pentathlon'}),
#  ('Tamara Press', {'discus throw', 'shot put'}),
#  ('Robert Hayes', {'100m', '4x100m relay'}),
#  ('Wyomia Tyus', {'100m', '4x100m relay'}),
#  ('Henry Carr', {'200m', '4x400m relay'}),
#  ('Michael Denny Larrabee', {'400m', '4x400m relay'}),
#  ('James Ray Hines', {'100m', '4x100m relay'}),
#  ('Kipchoge Keino', {'1500m', '3000m steeplechase'}),
#  ('Lee Edward Evans', {'400m', '4x400m relay'}),
#  ('Vincent Edward Matthews', {'400m', '4x400m relay'}),
#  ('Ingrid Becker-Mickler', {'4x100m relay', 'pentathlon'}),
#  ('Lasse Viren', {'10000m', '5000m'}),
#  ('Valery Borzov', {'100m', '200m'}),
#  ('Monika Zehrt', {'400m', '4x400m relay'}),
#  ('Annegret Richter-Irrgang', {'100m', '4x100m relay'}),
#  ('Heidemarie Rosendahl', {'4x100m relay', 'long jump'}),
#  ('Tatiana Kazankina', {'1500m', '800m'}),
#  ('Bärbel Eckert-Wöckel', {'200m', '4x100m relay'}),
#  ('Alberto Juantorena', {'400m', '800m'}),
#  ('Miruts Yifter', {'10000m', '5000m'}),
#  ('Viktor Markin', {'400m', '4x400m relay'}),
#  ('Evelyn Ashford', {'100m', '4x100m relay'}),
#  ('Alonzo C. Babers', {'400m', '4x400m relay'}),
#  ('Chandra Danette Cheeseborough', {'4x100m relay', '4x400m relay'}),
#  ('Steve Lewis', {'400m', '4x400m relay'}),
#  ('Olga Bryzgina', {'400m', '4x400m relay'}),
#  ('Jackie Joyner-Kersee', {'heptathlon', 'long jump'}),
#  ('Gail Devers', {'100m', '4x100m relay'}),
#  ('Michael Marsh', {'200m', '4x100m relay'}),
#  ('Gwen Torrence', {'200m', '4x100m relay'}),
#  ('Quincy Watts', {'400m', '4x400m relay'}),
#  ('Marie-Jose Perec', {'200m', '400m'}),
#  ('Donovan Bailey', {'100m', '4x100m relay'}),
#  ('Svetlana Masterkova', {'1500m', '800m'}),
#  ('Robert Korzeniowski', {'20km walk', '50km walk'}),
#  ('Maurice Greene', {'100m', '4x100m relay'}),
#  ('Pauline Elaine Davis', {'200m', '4x100m relay'}),
#  ('Angelo Taylor', {'400m hurdles', '4x400m relay'}),
#  ('Kenenisa Bekele', {'10000m', '5000m'}),
#  ('Hicham El guerrouj', {'1500m', '5000m'}),
#  ('Kelly Holmes', {'1500m', '800m'}),
#  ('Veronica Campbell-Brown', {'200m', '4x100m relay'}),
#  ('Jeremy Wariner', {'400m', '4x400m relay'}),
#  ('Meseret Defar', {'5000m', '5000m team'}),
#  ('LaShawn Merritt', {'400m', '4x400m relay'}),
#  ('Sanya Richards-Ross', {'400m', '4x400m relay'}),
#  ('Mo Farah', {'10miles walk (16093m)', '5000m team'}),
#  ('Elaine Thompson', {'100m', '200m'}),
#  ('Tianna Bartoletta', {'4x100m relay', 'long jump'}),
#  ('Mohamed Farah', {'10miles walk (16093m)', '5000m team'}),
#  ('Thomas Curtis', {'110m hurdles'}),
#  ('Spyridon Louis', {'marathon'}),
#  ('William Welles Hoyt', {'pole vault'}),
#  ('James Connolly', {'triple jump'}),
#  ('Francis Jarvis', {'100m'}),
#  ('George Orton', {'3000m steeplechase'}),
#  ('Maxwell W.Maxey Long', {'400m'}),
#  ('Sidney Robinson', {'5000m team'}),
#  ('Stanley Rowley', {'5000m team'}),
#  ('Rudolf Bauer', {'discus throw'}),
#  ('John Jesus Flanagan', {'hammer throw'}),
#  ('Michel Theato', {'marathon'}),
#  ('Richard Sheldon', {'shot put'}),
#  ('Frederick Schule', {'110m hurdles'}),
#  ('David Curtis Munson', {'4miles team'}),
#  ('Arthur Newton', {'4miles team'}),
#  ('Paul Harry Pilgrim', {'4miles team'}),
#  ('George Underwood', {'4miles team'}),
#  ('Howard Valentine', {'4miles team'}),
#  ('Etienne Desmarteau', {'56lb weight throw (25.4kg)'}),
#  ('Thomas Francis Kiely', {'decathlon'}),
#  ('Samuel Jones', {'high jump'}),
#  ('Thomas Hicks', {'marathon'}),
#  ('Charles Dvorak', {'pole vault'}),
#  ('Max Emmerich', {'triathlon (long jump / shot put / 100 yards)'}),
#  ('Reginald Walker', {'100m'}),
#  ('Forrest Smithson', {'110m hurdles'}),
#  ('Robert Kerr', {'200m'}),
#  ('Arthur Russell', {'3200m steeplechase'}),
#  ('William Coales', {'3miles team (4828m)'}),
#  ('Joseph Edmund Deakin', {'3miles team (4828m)'}),
#  ('Arthur James Robertson', {'3miles team (4828m)'}),
#  ('Wyndham Halswelle', {'400m'}),
#  ('Charles Joseph Bacon', {'400m hurdles'}),
#  ('John Nathaniel Cartmell', {'4x400m relay'}),
#  ('William Frank Hamilton', {'4x400m relay'}),
#  ('John Baxter Taylor', {'4x400m relay'}),
#  ('Emil Robert Voigt', {'5 miles (8047m)'}),
#  ('Harry Franklin Porter', {'high jump'}),
#  ('Francis C. Irons', {'long jump'}),
#  ('John Joseph Hayes', {'marathon'}),
#  ('Edward Tiffin Cooke', {'pole vault'}),
#  ('Alfred Carleten Gilbert', {'pole vault'}),
#  ('Timoty J. Ahearne', {'triple jump'}),
#  ('George Goulding', {'10000m walk'}),
#  ('Frederick Kelly', {'110m hurdles'}),
#  ('Arnold Jackson', {'1500m'}),
#  ('Tell Schirnding Berna', {'3000m team'}),
#  ('George V. Bonhag', {'3000m team'}),
#  ('Abel Kiviat', {'3000m team'}),
#  ('Henry Louis Scott', {'3000m team'}),
#  ('Norman Taber', {'3000m team'}),
#  ('William Applegarth', {'4x100m relay'}),
#  ("Victor Henry Augustus D'arcy", {'4x100m relay'}),
#  ('David Henry Jacobs', {'4x100m relay'}),
#  ('Henry Maitland Mackintosh', {'4x100m relay'}),
#  ('Edward F. Lindberg', {'4x400m relay'}),
#  ('Hjalmar Andersson', {'cross country team'}),
#  ('John Eke', {'cross country team'}),
#  ('Josef Ternström', {'cross country team'}),
#  ('Hugo K. Wieslander', {'decathlon'}),
#  ('Matthew J. Mcgrath', {'hammer throw'}),
#  ('Alma Wilfred Richards', {'high jump'}),
#  ('Platt Adams', {'high jump, standing'}),
#  ('Juho Julius Saaristo', {'javelin throw, both hands'}),
#  ('Albert Lovejoy Gutterson', {'long jump'}),
#  ('Konstantinos Tsiclitiras', {'long jump, standing'}),
#  ('Kennedy Kane Mcarthur', {'marathon'}),
#  ('Ferdinand Reinhardt Bie', {'pentathlon'}),
#  ('Harry Stoddard Babcock', {'pole vault'}),
#  ('Gustav Lindblom', {'triple jump'}),
#  ('Earl Thomson', {'110m hurdles'}),
#  ('Allen Woodring', {'200m'}),
#  ('Percy Hodge', {'3000m steeplechase'}),
#  ('Horace Hallock Brown', {'3000m team'}),
#  ('Ivan Dresser', {'3000m team'}),
#  ('Arlie Alfred Schardt', {'3000m team'}),
#  ("Bevil Gordon D'Urban Rudd", {'400m'}),
#  ('Frank Loomis', {'400m hurdles'}),
#  ('Morris Kirksey', {'4x100m relay'}),
#  ('Loren Murchison', {'4x100m relay'}),
#  ('John Creyghton Ainsworth-Davis', {'4x400m relay'}),
#  ('Guy Montagu Butler', {'4x400m relay'}),
#  ('Cecil Richmond Griffiths', {'4x400m relay'}),
#  ('Robert Alexander Lindsay', {'4x400m relay'}),
#  ('Joseph Guillemot', {'5000m'}),
#  ('Frederik Teudor Koskenniemi', {'cross country team'}),
#  ('Heikki Liimatainen', {'cross country team'}),
#  ('Helge Andreas Lövland', {'decathlon'}),
#  ('Elmer Konstantin Niklander', {'discus throw'}),
#  ('Patrick Ryan', {'hammer throw'}),
#  ('Richmond Landon', {'high jump'}),
#  ('Jonni Myyrä', {'javelin throw'}),
#  ('R. William E. Petersson', {'long jump'}),
#  ('Eero Reino Lehtonen', {'pentathlon'}),
#  ('Frank Foss', {'pole vault'}),
#  ('Frans Wilhelmi Pörhölä', {'shot put'}),
#  ('Vilho Immanuel Tuulos', {'triple jump'}),
#  ('Harold Abrahams', {'100m'}),
#  ('Daniel Kinsey', {'110m hurdles'}),
#  ('Elias Katz', {'3000m team'}),
#  ('Frej Liewendhal', {'3000m team'}),
#  ('Eino Seppälä', {'3000m team'}),
#  ('S. Talja', {'3000m team'}),
#  ('Eric Henry Liddell', {'400m'}),
#  ('Frederick Morgan Taylor', {'400m hurdles'}),
#  ('Louis Alfred Clarke', {'4x100m relay'}),
#  ('Francis Hussey', {'4x100m relay'}),
#  ('Jeremiah Alfred Leconey', {'4x100m relay'}),
#  ('Commodore Cochrane', {'4x400m relay'}),
#  ('Alan Helffrich', {'4x400m relay'}),
#  ('J. Oliver Macdonald', {'4x400m relay'}),
#  ('William Stephenson', {'4x400m relay'}),
#  ('Douglas Gordon Lowe', {'800m'}),
#  ('Eero Berg', {'cross country team'}),
#  ('Eino Rastas', {'cross country team'}),
#  ('Väinö Jeremias Sipilä', {'cross country team'}),
#  ('Frederick Delmont Tootell', {'hammer throw'}),
#  ('William De Hart Hubbard', {'long jump'}),
#  ('Albin Oskar Stenroos', {'marathon'}),
#  ('Lee Barnes', {'pole vault'}),
#  ('Anthony William Winter', {'triple jump'}),
#  ('Sidney Atkinson', {'110m hurdles'}),
#  ('Harri Edvin Larva', {'1500m'}),
#  ('Toivo Aarne Loukola', {'3000m steeplechase'}),
#  ('David George Burghley', {'400m hurdles'}),
#  ('Charles Edward Borah', {'4x100m relay'}),
#  ('James F. Quinn', {'4x100m relay'}),
#  ('Henry Argue Russell', {'4x100m relay'}),
#  ('Frank Clifford Wykoff', {'4x100m relay'}),
#  ('Myrtle Alice Cook', {'4x100m relay'}),
#  ('Fanny Rosenfeld', {'4x100m relay'}),
#  ('Ethel M. Smith', {'4x100m relay'}),
#  ('Jean Thompson', {'4x100m relay'}),
#  ('Frederick Pitt Alderman', {'4x400m relay'}),
#  ('George Hetzel Baird', {'4x400m relay'}),
#  ('Emerson Lane Spencer', {'4x400m relay'}),
#  ('Karoline "Lina" Radke', {'800m'}),
#  ('Paavo Ilmari Yrjölä', {'decathlon'}),
#  ('Halina Konopacka', {'discus throw'}),
#  ("Patrick O'callaghan", {'hammer throw'}),
#  ('Robert Wade King', {'high jump'}),
#  ('Ethel Catherwood', {'high jump'}),
#  ('Erik H. Lundqvist', {'javelin throw'}),
#  ('Edward Barton Hamm', {'long jump'}),
#  ('Boughera Mohamed El Ouafi', {'marathon'}),
#  ('Sabin William Carr', {'pole vault'}),
#  ('John H. Kuck', {'shot put'}),
#  ('Mikio Oda', {'triple jump'}),
#  ('Janusz Kusocinski', {'10000m'}),
#  ('Stanislawa Walasiewicz', {'100m'}),
#  ('George J. Jr. Saling', {'110m hurdles'}),
#  ('Luigi Beccali', {'1500m'}),
#  ('Volmari Iso-Hollo', {'3000m steeplechase'}),
#  ('Robert Morton Newburgh Tisdall', {'400m hurdles'}),
#  ('Hector Monroe Dyer', {'4x100m relay'}),
#  ('Robert Allan Kiesel', {'4x100m relay'}),
#  ('Martin Emmett Toppino', {'4x100m relay'}),
#  ('Mary Louise Carew', {'4x100m relay'}),
#  ('Evelyn Furtsch', {'4x100m relay'}),
#  ('Annette Joan Rogers', {'4x100m relay'}),
#  ('Wilhelmina Von bremen', {'4x100m relay'}),
#  ('Edgar Allen Ablowich', {'4x400m relay'}),
#  ('Ivan William Fuqua', {'4x400m relay'}),
#  ('Karl De Witt Warner', {'4x400m relay'}),
#  ('Lauri Aleksanteri Lehtinen', {'5000m'}),
#  ('Thomas William Green', {'50km walk'}),
#  ('Thomas Hampson', {'800m'}),
#  ('James Aloysius Bernard Bausch', {'decathlon'}),
#  ('John Franklin Anderson', {'discus throw'}),
#  ('Lillian Copeland', {'discus throw'}),
#  ('Duncan Mcnaughton', {'high jump'}),
#  ('Jean Shiley', {'high jump'}),
#  ('Matti Henrik Jarvinen', {'javelin throw'}),
#  ('Edward Lansing Gordon', {'long jump'}),
#  ('Juan Carlos Zabala', {'marathon'}),
#  ('William Waring Miller', {'pole vault'}),
#  ('Leo Joseph Sexton', {'shot put'}),
#  ('Chuhei Nambu', {'triple jump'}),
#  ('Ilmari Salminen', {'10000m'}),
#  ('Forrest Grady Towns', {'110m hurdles'}),
#  ('John Lovelock', {'1500m'}),
#  ('Archibald Franklin Williams', {'400m'}),
#  ('Glenn Foster Hardin', {'400m hurdles'}),
#  ('Foy Draper', {'4x100m relay'}),
#  ('Ralph Metcalfe', {'4x100m relay'}),
#  ('Harriett Claiborne Bland', {'4x100m relay'}),
#  ('Arthur Godfrey Kilner Brown', {'4x400m relay'}),
#  ('Godfrey Lionel Rampling', {'4x400m relay'}),
#  ('William Roberts', {'4x400m relay'}),
#  ('Frederick Ferdinand Wolff', {'4x400m relay'}),
#  ('Gunnar Höckert', {'5000m'}),
#  ('Hector Harold Whitlock', {'50km walk'}),
#  ('John Youie Woodruff', {'800m'}),
#  ('Trebisonda Valla', {'80m hurdles'}),
#  ('Glenn Edward Morris', {'decathlon'}),
#  ('William Kenneth Carpenter', {'discus throw'}),
#  ('Gisela Mauermayer', {'discus throw'}),
#  ('Karl Hein', {'hammer throw'}),
#  ('Cornelius Cooper Johnson', {'high jump'}),
#  ('Ibolya Csak', {'high jump'}),
#  ('Gerhard (Gerd) Stöck', {'javelin throw'}),
#  ('Mathilde (Tilly) Fleischer', {'javelin throw'}),
#  ('Kitei Son', {'marathon'}),
#  ('Earle Elmer Meadows', {'pole vault'}),
#  ('Hans Woellke', {'shot put'}),
#  ('Naoto Tajima', {'triple jump'}),
#  ('John Mikaelsson', {'10000m walk'}),
#  ('William Franklin III Porter', {'110m hurdles'}),
#  ('Henry Eriksson', {'1500m'}),
#  ('Tore Sjöstrand', {'3000m steeplechase'}),
#  ('Harold Norwood Ewell', {'4x100m relay'}),
#  ('Lorenzo Christopher Wright', {'4x100m relay'}),
#  ('Xenia Stad-De jong', {'4x100m relay'}),
#  ('Gerda Johanna Marie Van der kade-Koudijs', {'4x100m relay'}),
#  ('Jeannette Josephina Maria Witziers-Timmer', {'4x100m relay'}),
#  ('Clifford Frederick Bourland', {'4x400m relay'}),
#  ('Arthur Harold Harnden', {'4x400m relay'}),
#  ('Gaston Etienne Reiff', {'5000m'}),
#  ('John Artur Ljunggren', {'50km walk'}),
#  ('Robert Mathias', {'decathlon'}),
#  ('Adolfo Consolini', {'discus throw'}),
#  ('Imre Nemeth', {'hammer throw'}),
#  ('John Winter', {'high jump'}),
#  ('Alice Marie Coachman', {'high jump'}),
#  ('Kaj Tapio Rautavaara', {'javelin throw'}),
#  ('Hermine (Herma) Bauma', {'javelin throw'}),
#  ('William Samuel Steele', {'long jump'}),
#  ('Olga Gyarmati', {'long jump'}),
#  ('Delfo Cabrera', {'marathon'}),
#  ('Owen Guinn Smith', {'pole vault'}),
#  ('Wilbur Marvin Thompson', {'shot put'}),
#  ('Arne Ahman', {'triple jump'}),
#  ('Joseph Barthel', {'1500m'}),
#  ('Horace III Ashenfelter', {'3000m steeplechase'}),
#  ('Charles Hewes Jr. Moore', {'400m hurdles'}),
#  ('Finis Dean Smith', {'4x100m relay'}),
#  ('Mae Heriwentha Faggs', {'4x100m relay'}),
#  ('Catherine Hardy', {'4x100m relay'}),
#  ('Barbara Pearl Jones', {'4x100m relay'}),
#  ('Janet Theresa Moreau', {'4x100m relay'}),
#  ('Leslie Laing', {'4x400m relay'}),
#  ('Herbert Mckenley', {'4x400m relay'}),
#  ('Giuseppe Dordoni', {'50km walk'}),
#  ('Simeon Garland Iness', {'discus throw'}),
#  ('Nina Romashkova-Ponomareva', {'discus throw'}),
#  ('Jozsef Csermak', {'hammer throw'}),
#  ('Walter Francis Davis', {'high jump'}),
#  ('Esther Cornelia Brand', {'high jump'}),
#  ('Cyrus C. Jr. Young', {'javelin throw'}),
#  ('Dana Ingrova-Zatopkova', {'javelin throw'}),
#  ('Jerome Cousins Biffle', {'long jump'}),
#  ('Yvette Winefred Williams', {'long jump'}),
#  ('Robert Richards', {'pole vault'}),
#  ('William Patrick Jr. O', {'shot put'}),
#  ('Galina Zybina', {'shot put'}),
#  ('Adhemar Ferreira Da Silva', {'triple jump'}),
#  ('Lee Calhoun', {'110m hurdles'}),
#  ('Ronald Michael Delany', {'1500m'}),
#  ('Leonid Spirin', {'20km walk'}),
#  ('Christopher William Brasher', {'3000m steeplechase'}),
#  ('Walter Thane Baker', {'4x100m relay'}),
#  ('Leamon King', {'4x100m relay'}),
#  ('Ira James Murchison', {'4x100m relay'}),
#  ('Norma Wilson Crooker-Fleming', {'4x100m relay'}),
#  ('Fluer Northey Mellor-Wenham', {'4x100m relay'}),
#  ('Louis Woodard III Jones', {'4x400m relay'}),
#  ('Jesse William Mashburn', {'4x400m relay'}),
#  ('Norman Richard Read', {'50km walk'}),
#  ('Milton Gray Campbell', {'decathlon'}),
#  ('Alfred Oerter', {'discus throw'}),
#  ('Olga Fikotova-Connolly', {'discus throw'}),
#  ('Harold Vincent Connolly', {'hammer throw'}),
#  ('Charles Everett Dumas', {'high jump'}),
#  ('Mildred Louise Mcdaniel', {'high jump'}),
#  ('Egil Danielsen', {'javelin throw'}),
#  ('Inese Yaunzeme', {'javelin throw'}),
#  ('Gregory Curtis Bell', {'long jump'}),
#  ('Elzbieta Dunska-Krzesinska', {'long jump'}),
#  ('Alain Mimoun', {'marathon'}),
#  ('Tamara Tyshkevich', {'shot put'}),
#  ('Pyotr Bolotnikov', {'10000m'}),
#  ('Herbert Elliott', {'1500m'}),
#  ('Livio Berruti', {'200m'}),
#  ('Vladimir Golubnichy', {'20km walk'}),
#  ('Zdzislaw Krzyszkowiak', {'3000m steeplechase'}),
#  ('Bernd Cullmann', {'4x100m relay'}),
#  ('Martin Lauer', {'4x100m relay'}),
#  ('Walter Mahlendorf', {'4x100m relay'}),
#  ('Martha B. Hudson', {'4x100m relay'}),
#  ('Lucinda Williams', {'4x100m relay'}),
#  ('John Lloyd Yerman', {'4x400m relay'}),
#  ('Earl Verdelle Young', {'4x400m relay'}),
#  ('Murray Gordon Halberg', {'5000m'}),
#  ('Donald James Thompson', {'50km walk'}),
#  ('Lyudmila Lisenko-Shevtsova', {'800m'}),
#  ('Rafer Lewis Johnson', {'decathlon'}),
#  ('Vasili Rudenkov', {'hammer throw'}),
#  ('Robert Shavlakadze', {'high jump'}),
#  ('Iolanda Balas', {'high jump'}),
#  ('Viktor Tsybulenko', {'javelin throw'}),
#  ('Elvira Ozolina', {'javelin throw'}),
#  ('Ralph Harold Boston', {'long jump'}),
#  ('Vera Kolashnikova-Krepkina', {'long jump'}),
#  ('Abebe Bikila', {'marathon'}),
#  ('Donald George Bragg', {'pole vault'}),
#  ('William Henry Nieder', {'shot put'}),
#  ('Jozef Schmidt', {'triple jump'}),
#  ('William Mills', {'10000m'}),
#  ('Hayes Jones', {'110m hurdles'}),
#  ('Edith Marie Mcguire', {'200m'}),
#  ('Kenneth Joseph Matthews', {'20km walk'}),
#  ('Gaston Roelants', {'3000m steeplechase'}),
#  ('Warren (Rex) Jay Cawley', {'400m hurdles'}),
#  ('Gerald Howard Ashworth', {'4x100m relay'}),
#  ('Otis Paul Drayton', {'4x100m relay'}),
#  ('Richard Vaughn Stebbins', {'4x100m relay'}),
#  ('Halina Herrmann-Gorecka-Richter', {'4x100m relay'}),
#  ('Ewa Klobukowska', {'4x100m relay'}),
#  ('Teresa Barbara Wieczorek-Cieply', {'4x100m relay'}),
#  ('Ollan Conley Cassell', {'4x400m relay'}),
#  ('Ulis C. Williams', {'4x400m relay'}),
#  ('Robert Keyser Schul', {'5000m'}),
#  ('Abdon Pamich', {'50km walk'}),
#  ('Ann Elizabeth Packer', {'800m'}),
#  ('Karin Richert-Balzer', {'80m hurdles'}),
#  ('Willi Holdorf', {'decathlon'}),
#  ('Romuald Klim', {'hammer throw'}),
#  ('Valeri Brumel', {'high jump'}),
#  ('Pauli Lauri Nevala', {'javelin throw'}),
#  ('Mihaela Penes', {'javelin throw'}),
#  ('Lynn Davies', {'long jump'}),
#  ('Mary Denise Bignal-Rand', {'long jump'}),
#  ('Frederick Morgan Hansen', {'pole vault'}),
#  ('Dallas Crutcher III Long', {'shot put'}),
#  ('Nabiba Naftali Temu', {'10000m'}),
#  ('Willie Davenport', {'110m hurdles'}),
#  ('Thomas C. Smith', {'200m'}),
#  ('Amos Kipwabok Biwott', {'3000m steeplechase'}),
#  ('Colette Besson', {'400m'}),
#  ('David Peter Hemery', {'400m hurdles'}),
#  ('Charles Edward Greene', {'4x100m relay'}),
#  ('Melvin Jr. Pender', {'4x100m relay'}),
#  ('Ronald Ray Smith', {'4x100m relay'}),
#  ('Margaret Johnson Bailes', {'4x100m relay'}),
#  ('Barbara Ann Ferrell', {'4x100m relay'}),
#  ('Mildrette Netter', {'4x100m relay'}),
#  ('Ronald John III Freeman', {'4x400m relay'}),
#  ('George Lawrence James', {'4x400m relay'}),
#  ('Mohamed Gammoudi', {'5000m'}),
#  ('Christoph Höhne', {'50km walk'}),
#  ('Ralph Doubell', {'800m'}),
#  ('Madeline Manning-Jackson', {'800m'}),
#  ('Maureen Caird', {'80m hurdles'}),
#  ('William Anthony Toomey', {'decathlon'}),
#  ('Lia Manoliu', {'discus throw'}),
#  ('Gyula Zsivotzky', {'hammer throw'}),
#  ('Richard Douglas Fosbury', {'high jump'}),
#  ('Miloslava Rezkova-Hubner', {'high jump'}),
#  ('Yanis Lusis', {'javelin throw'}),
#  ('Angela Nemeth-Ranky', {'javelin throw'}),
#  ('Bob Beamon', {'long jump'}),
#  ('Viorica Viscopoleanu', {'long jump'}),
#  ('Mamo Wolde', {'marathon'}),
#  ('Robert Lloyd Seagren', {'pole vault'}),
#  ('James Randel Matson', {'shot put'}),
#  ('Margitta Helmbold-Gummel', {'shot put'}),
#  ('Viktor Saneev', {'triple jump'}),
#  ('Annelie Ehrhardt', {'100m hurdles'}),
#  ('Rodney Jr. Milburn', {'110m hurdles'}),
#  ('Pekka Vasala', {'1500m'}),
#  ('Lyudmila Bragina', {'1500m'}),
#  ('Peter Frenkel', {'20km walk'}),
#  ('John Akii-Bua', {'400m hurdles'}),
#  ('Lawrence J. Black', {'4x100m relay'}),
#  ('Edward James Hart', {'4x100m relay'}),
#  ('Robert Taylor', {'4x100m relay'}),
#  ('Gerald A. Tinker', {'4x100m relay'}),
#  ('Christiane Krause', {'4x100m relay'}),
#  ('Charles Asati', {'4x400m relay'}),
#  ('Hezekiah Munyoro Nyamau', {'4x400m relay'}),
#  ('Robert Ouko', {'4x400m relay'}),
#  ('Julius Sang', {'4x400m relay'}),
#  ('Dagmar Käsling', {'4x400m relay'}),
#  ('Rita Kühne', {'4x400m relay'}),
#  ('Helga Seidler', {'4x400m relay'}),
#  ('Bernd Kannenberg', {'50km walk'}),
#  ('David James Wottle', {'800m'}),
#  ('Hildegard Falck-Janze', {'800m'}),
#  ('Nikolai Avilov', {'decathlon'}),
#  ('Ludvik Danek', {'discus throw'}),
#  ('Faina Melnik', {'discus throw'}),
#  ('Anatoli Bondarchuk', {'hammer throw'}),
#  ('Yuri Tarmak', {'high jump'}),
#  ('Ulrike Meyfarth', {'high jump'}),
#  ('Klaus Wolfermann', {'javelin throw'}),
#  ('Ruth Fuchs', {'javelin throw'}),
#  ('Randel Luvelle Williams', {'long jump'}),
#  ('Frank Charles Shorter', {'marathon'}),
#  ('Mary Peters', {'pentathlon'}),
#  ('Wolfgang Nordwig', {'pole vault'}),
#  ('Wladyslaw Komar', {'shot put'}),
#  ('Nadezhda Chizhova', {'shot put'}),
#  ('Hasely Crawford', {'100m'}),
#  ('Johanna Schaller-Klier', {'100m hurdles'}),
#  ('Guy Drut', {'110m hurdles'}),
#  ('John Walker', {'1500m'}),
#  ('Donald Quarrie', {'200m'}),
#  ('Daniel Bautista rocha', {'20km walk'}),
#  ('Anders Garderud', {'3000m steeplechase'}),
#  ('Edwin Moses', {'400m hurdles'}),
#  ('Harvey Edward Glance', {'4x100m relay'}),
#  ('Millard Frank Jr. Hampton', {'4x100m relay'}),
#  ('John Wesley Jones', {'4x100m relay'}),
#  ('Steven Earl Riddick', {'4x100m relay'}),
#  ('Carla Bodendorf', {'4x100m relay'}),
#  ('Marlies Oelsner-Göhr', {'4x100m relay'}),
#  ('Benjamin Gene Brown', {'4x400m relay'}),
#  ('Herman Ronald Frazier', {'4x400m relay'}),
#  ('Frederick Vaughn Newhouse', {'4x400m relay'}),
#  ('Maxwell Lander Parks', {'4x400m relay'}),
#  ('Christina Brehmer-Lathan', {'4x400m relay'}),
#  ('Doris Maletzki', {'4x400m relay'}),
#  ('Brigitte Rohde', {'4x400m relay'}),
#  ('Ellen Stropahl-Streidt', {'4x400m relay'}),
#  ('William Bruce Jenner', {'decathlon'}),
#  ('Malcolm Maurice Wilkins', {'discus throw'}),
#  ('Evelin Schlaak-Jahl', {'discus throw'}),
#  ('Yuri Sedykh', {'hammer throw'}),
#  ('Jacek Wszola', {'high jump'}),
#  ('Rosemarie Witschas-Ackermann', {'high jump'}),
#  ('Miklos Nemeth', {'javelin throw'}),
#  ('Arnie Robinson', {'long jump'}),
#  ('Angela Voigt', {'long jump'}),
#  ('Waldemar Cierpinski', {'marathon'}),
#  ('Siegrun Siegl', {'pentathlon'}),
#  ('Tadeusz Slusarski', {'pole vault'}),
#  ('Udo Beyer', {'shot put'}),
#  ('Ivanka Mikailova Christova-Todorova', {'shot put'}),
#  ('Allan Wells', {'100m'}),
#  ('Liudmila Kondratieva', {'100m'}),
#  ('Vera Komisova', {'100m hurdles'}),
#  ('Thomas Munkelt', {'110m hurdles'}),
#  ('Sebastian Coe', {'1500m'}),
#  ('Pietro Mennea', {'200m'}),
#  ('Maurizio Damilano', {'20km walk'}),
#  ('Bronislaw Malinowski', {'3000m steeplechase'}),
#  ('Marita Koch', {'400m'}),
#  ('Volker Beck', {'400m hurdles'}),
#  ('Aleksandr Aksinin', {'4x100m relay'}),
#  ('Vladimir Muravyov', {'4x100m relay'}),
#  ('Andrei Prokofiev', {'4x100m relay'}),
#  ('Nikolai Sidorov', {'4x100m relay'}),
#  ('Ingrid Auerswald-Lange', {'4x100m relay'}),
#  ('Romy Müller', {'4x100m relay'}),
#  ('Nikolai Chernetski', {'4x400m relay'}),
#  ('Mikhail Linge', {'4x400m relay'}),
#  ('Remigius Valiulis', {'4x400m relay'}),
#  ('Tatiana Goishchik', {'4x400m relay'}),
#  ('Irina Nazarova', {'4x400m relay'}),
#  ('Tatiana Prorochenko', {'4x400m relay'}),
#  ('Nina Ziuskova', {'4x400m relay'}),
#  ('Hartwig Gauder', {'50km walk'}),
#  ('Steve Ovett', {'800m'}),
#  ('Nadezhda Olizarenko', {'800m'}),
#  ('Daley Thompson', {'decathlon'}),
#  ('Viktor Rashchupkin', {'discus throw'}),
#  ('Gerd Wessig', {'high jump'}),
#  ('Sara Simeoni', {'high jump'}),
#  ('Dainis Kula', {'javelin throw'}),
#  ('Maria Colon', {'javelin throw'}),
#  ('Lutz Dombrowski', {'long jump'}),
#  ('Tatiana Kolpakova', {'long jump'}),
#  ('Nadezhda Tkachenko', {'pentathlon'}),
#  ('Wladyslaw Kozakiewicz', {'pole vault'}),
#  ('Vladimir Kiselev', {'shot put'}),
#  ('Ilona Schoknecht-Slupianek', {'shot put'}),
#  ('Yaak Uudmae', {'triple jump'}),
#  ('Alberto Cova', {'10000m'}),
#  ('Benita Fitzgerald-Brown', {'100m hurdles'}),
#  ('Roger Kingdom', {'110m hurdles'}),
#  ('Gabriella Dorio', {'1500m'}),
#  ('Ernesto Canto gudino', {'20km walk'}),
#  ('Maricica Puica', {'3000m'}),
#  ('Julius Korir', {'3000m steeplechase'}),
#  ('Nawal El moutawakel', {'400m hurdles'}),
#  ('Ronald James Brown', {'4x100m relay'}),
#  ('Samuel Louis Graddy', {'4x100m relay'}),
#  ('Calvin Smith', {'4x100m relay'}),
#  ('Jeanette Bolden', {'4x100m relay'}),
#  ('Alice Regina Brown', {'4x100m relay'}),
#  ('Raymond Armstead', {'4x400m relay'}),
#  ('Antonio Ricardo Mckay', {'4x400m relay'}),
#  ('Sunder L. Nix', {'4x400m relay'}),
#  ('Sherryl Frances Howard', {'4x400m relay'}),
#  ('Lillie Mae Leatherwood-King', {'4x400m relay'}),
#  ('Said Aouita', {'5000m'}),
#  ('Raul Gonzalez', {'50km walk'}),
#  ('Joaquim Cruz', {'800m'}),
#  ('Doina Besliu-Melinte', {'800m'}),
#  ('Rolf Danneberg', {'discus throw'}),
#  ('Ria G. Stalman', {'discus throw'}),
#  ('Juha Tiainen', {'hammer throw'}),
#  ('Glyniss Leanne Nunn-Saunders-Cearns', {'heptathlon'}),
#  ('Dietmar Mögenburg', {'high jump'}),
#  ('Arto Harkonen', {'javelin throw'}),
#  ('Teresa Sanderson', {'javelin throw'}),
#  ('Anisoara Cusmir-Stanciu', {'long jump'}),
#  ('Carlos Lopes', {'marathon'}),
#  ('Joan Benoit', {'marathon'}),
#  ('Pierre Quinon', {'pole vault'}),
#  ('Alessandro Andrei', {'shot put'}),
#  ('Claudia Losch', {'shot put'}),
#  ('Alfredrick Alphonzo Joyner', {'triple jump'}),
#  ('Moulay Brahim Boutayeb', {'10000m'}),
#  ('Olga Bondarenko', {'10000m'}),
#  ('Yordanka Donkova', {'100m hurdles'}),
#  ('Peter Rono', {'1500m'}),
#  ('Paula Ivan', {'1500m'}),
#  ('Joseph Nathaniel Jr. Deloach', {'200m'}),
#  ('Jozef Pribilinec', {'20km walk'}),
#  ('Tatyana Samolenko-Dorovskikh', {'3000m'}),
#  ('Julius Kariuki', {'3000m steeplechase'}),
#  ('Andre Lamar Phillips', {'400m hurdles'}),
#  ('Deborah Flintoff-King', {'400m hurdles'}),
#  ('Viktor Bryzgin', {'4x100m relay'}),
#  ('Vladimir Krylov', {'4x100m relay'}),
#  ('Vitaly Savin', {'4x100m relay'}),
#  ('Sheila Echols', {'4x100m relay'}),
#  ('Daniel Everett', {'4x400m relay'}),
#  ('Harry Butch . Reynolds', {'4x400m relay'}),
#  ('Kevin Bernard Robinzine', {'4x400m relay'}),
#  ('Tatiana Ledovskaya', {'4x400m relay'}),
#  ('Olga Nazarova', {'4x400m relay'}),
#  ('Mariya Pinigina', {'4x400m relay'}),
#  ('John Ngugi', {'5000m'}),
#  ('Vyacheslav Ivanenko', {'50km walk'}),
#  ('Paul Ereng', {'800m'}),
#  ('Sigrun Wodars', {'800m'}),
#  ('Christian Schenk', {'decathlon'}),
#  ('Jürgen Schult', {'discus throw'}),
#  ('Martina Hellmann', {'discus throw'}),
#  ('Sergei Litvinov', {'hammer throw'}),
#  ('Gennadi Avdeenko', {'high jump'}),
#  ('Dorothy Louise Ritter', {'high jump'}),
#  ('Tapio Korjus', {'javelin throw'}),
#  ('Petra Felke-Meier', {'javelin throw'}),
#  ('Gelindo Bordin', {'marathon'}),
#  ('Rosa Mota', {'marathon'}),
#  ('Sergey Bubka', {'pole vault'}),
#  ('Ulf Timmermann', {'shot put'}),
#  ('Natalya Lisovskaya', {'shot put'}),
#  ('Kristo Gantchev Markov', {'triple jump'}),
#  ('Khalid Skah', {'10000m'}),
#  ('Derartu Tulu', {'10000m'}),
#  ('Yueling Chen', {'10000m walk'}),
#  ('Linford Christie', {'100m'}),
#  ('Paraskevi Voula Patoulidou', {'100m hurdles'}),
#  ('Mark Mckoy', {'110m hurdles'}),
#  ('Fermin Cacho ruiz', {'1500m'}),
#  ('Hassiba Boulmerka', {'1500m'}),
#  ('Daniel Plaza montero', {'20km walk'}),
#  ('Elena Romanova', {'3000m'}),
#  ('Mathew Birir', {'3000m steeplechase'}),
#  ('Kevin Curtis Young', {'400m hurdles'}),
#  ('Sally Janet Jane Gunnell', {'400m hurdles'}),
#  ('Leroy Burrell', {'4x100m relay'}),
#  ('James Jett', {'4x100m relay'}),
#  ('Dennis Mitchell', {'4x100m relay'}),
#  ('Michelle Finn', {'4x100m relay'}),
#  ('Carlette D. Guidry-White', {'4x100m relay'}),
#  ('Esther Jones', {'4x100m relay'}),
#  ('Darnell Hall', {'4x400m relay'}),
#  ('Charles L. Jenkins', {'4x400m relay'}),
#  ('Andrew Valmon', {'4x400m relay'}),
#  ('Marina Chmonina', {'4x400m relay'}),
#  ('Lioudmila Djigalova', {'4x400m relay'}),
#  ('Lilia Nurutdinova', {'4x400m relay'}),
#  ('Yelena Rouzina', {'4x400m relay'}),
#  ('Dieter Baumann', {'5000m'}),
#  ('Andrey Perlov', {'50km walk'}),
#  ('William Tanui', {'800m'}),
#  ('Ellen Van langen', {'800m'}),
#  ('Robert Zmelik', {'decathlon'}),
#  ('Romas Ubartas', {'discus throw'}),
#  ('Maritza Marten', {'discus throw'}),
#  ('Andrey Abduvaliev', {'hammer throw'}),
#  ('Javier Sotomayor', {'high jump'}),
#  ('Heike Henkel', {'high jump'}),
#  ('Jan Zelezny', {'javelin throw'}),
#  ('Silke Renk', {'javelin throw'}),
#  ('Heike Drechsler', {'long jump'}),
#  ('Young-Cho Hwang', {'marathon'}),
#  ('Valentina Yegorova', {'marathon'}),
#  ('Maksim Tarasov', {'pole vault'}),
#  ('Michael D. Stulce', {'shot put'}),
#  ('Svetlana Krivelyova', {'shot put'}),
#  ('Mike Conley', {'triple jump'}),
#  ('Haile Gebrselassie', {'10000m'}),
#  ('Fernanda Ribeiro', {'10000m'}),
#  ('Yelena Nikolayeva', {'10000m walk'}),
#  ('Ludmila Engquist', {'100m hurdles'}),
#  ('Allen Johnson', {'110m hurdles'}),
#  ('Nourredine Morceli', {'1500m'}),
#  ('Jefferson Perez', {'20km walk'}),
#  ('Joseph Keter', {'3000m steeplechase'}),
#  ('Derrick Adkins', {'400m hurdles'}),
#  ('Deon Marie Hemmings', {'400m hurdles'}),
#  ('Carlton Chambers', {'4x100m relay'}),
#  ('Robert Esmie', {'4x100m relay'}),
#  ('Glenroy Gilbert', {'4x100m relay'}),
#  ('Bruny Surin', {'4x100m relay'}),
#  ('Chryste Gaines', {'4x100m relay'}),
#  ('Inger Miller', {'4x100m relay'}),
#  ('Alvin Harrison', {'4x400m relay'}),
#  ('Anthuan Maybank', {'4x400m relay'}),
#  ('Derek Mills', {'4x400m relay'}),
#  ('Jason Rouser', {'4x400m relay'}),
#  ('Lamont Smith', {'4x400m relay'}),
#  ('Kim Graham', {'4x400m relay'}),
#  ('Maicel Malone', {'4x400m relay'}),
#  ('Jearl Miles', {'4x400m relay'}),
#  ('Rochelle Stevens', {'4x400m relay'}),
#  ('Linetta Wilson', {'4x400m relay'}),
#  ('Venuste Niyongabo', {'5000m'}),
#  ('Junxia Wang', {'5000m'}),
#  ('Vebjorn Rodal', {'800m'}),
#  ("Dan O'brien", {'decathlon'}),
#  ('Lars Riedel', {'discus throw'}),
#  ('Ilke Wyludda', {'discus throw'}),
#  ('Balazs Kiss', {'hammer throw'}),
#  ('Ghada Shouaa', {'heptathlon'}),
#  ('Charles Austin', {'high jump'}),
#  ('Stefka Kostadinova', {'high jump'}),
#  ('Heli Orvokki Rantanen', {'javelin throw'}),
#  ('Chioma Ajunwa', {'long jump'}),
#  ('Josia Thugwane', {'marathon'}),
#  ('Fatuma Roba', {'marathon'}),
#  ('Jean Galfione', {'pole vault'}),
#  ('Eric Randolph Barnes', {'shot put'}),
#  ('Astrid Kumbernuss', {'shot put'}),
#  ('Kenny Harrison', {'triple jump'}),
#  ('Inessa Kravets', {'triple jump'}),
#  ('Olga Shishigina', {'100m hurdles'}),
#  ('Anier Garcia', {'110m hurdles'}),
#  ('Noah Kiprono Ngenyi', {'1500m'}),
#  ('Nouria Merah-Benida', {'1500m'}),
#  ('Konstantinos Kenteris', {'200m'}),
#  ('Liping Wang', {'20km race walk'}),
#  ('Reuben Kosgei', {'3000m steeplechase'}),
#  ('Cathy Freeman', {'400m'}),
#  ('Irina Privalova', {'400m hurdles'}),
#  ('Kenneth Brokenburr', {'4x100m relay'}),
#  ('Jon Drummond', {'4x100m relay'}),
#  ('Brian Lewis', {'4x100m relay'}),
#  ('Tim Montgomery', {'4x100m relay'}),
#  ('Bernard Williams iii', {'4x100m relay'}),
#  ('Debbie Ferguson-Mckenzie', {'4x100m relay'}),
#  ('Sevatheda Fynes', {'4x100m relay'}),
#  ('Eldice Lewis', {'4x100m relay'}),
#  ('Chandra Sturrup', {'4x100m relay'}),
#  ('Andrea Anderson', {'4x400m relay'}),
#  ('LaTasha Colander', {'4x400m relay'}),
#  ('Monique Hennagan', {'4x400m relay'}),
#  ('Millon Wolde', {'5000m'}),
#  ('Gabriela Szabo', {'5000m'}),
#  ('Nils Schumann', {'800m'}),
#  ('Maria Mutola', {'800m'}),
#  ('Erki Nool', {'decathlon'}),
#  ('Virgilijus Alekna', {'discus throw'}),
#  ('Ellina Zvereva', {'discus throw'}),
#  ('Szymon Ziolkowski', {'hammer throw'}),
#  ('Kamila Skolimowska', {'hammer throw'}),
#  ('Denise Lewis', {'heptathlon'}),
#  ('Sergey Kliugin', {'high jump'}),
#  ('Yelena Yelesina', {'high jump'}),
#  ('Trine Hattestad', {'javelin throw'}),
#  ('Ivan Pedroso', {'long jump'}),
#  ('Gezahegne Abera', {'marathon'}),
#  ('Naoko Takahashi', {'marathon'}),
#  ('Nick Hysong', {'pole vault'}),
#  ('Stacy Dragila', {'pole vault'}),
#  ('Arsi Harju', {'shot put'}),
#  ('Yanina Karolchik', {'shot put'}),
#  ('Jonathan David Edwards', {'triple jump'}),
#  ('Tereza Marinova', {'triple jump'}),
#  ('Huina Xing', {'10000m'}),
#  ('Justin Gatlin', {'100m'}),
#  ('Yuliya Nesterenko', {'100m'}),
#  ('Joanna Hayes', {'100m hurdles'}),
#  ('Xiang Liu', {'110m hurdles'}),
#  ('Shawn Crawford', {'200m'}),
#  ('Athanasia Tsoumeleka', {'20km race walk'}),
#  ('Ivano Brugnetti', {'20km walk'}),
#  ('Ezekiel Kemboi', {'3000m steeplechase'}),
#  ('Tonique Williams-Darling', {'400m'}),
#  ('Felix Sanchez', {'400m hurdles'}),
#  ('Fani Chalkia', {'400m hurdles'}),
#  ('Darren Campbell', {'4x100m relay'}),
#  ('Marlon Devonish', {'4x100m relay'}),
#  ('Jason Gardener', {'4x100m relay'}),
#  ('Mark Lewis-Francis', {'4x100m relay'}),
#  ('Aleen Bailey', {'4x100m relay'}),
#  ('Tanya Lawrence', {'4x100m relay'}),
#  ('Beverly Mcdonald', {'4x100m relay'}),
#  ('Sherone Simpson', {'4x100m relay'}),
#  ('Derrick Brew', {'4x400m relay'}),
#  ('Otis Harris', {'4x400m relay'}),
#  ('Darold Williamson', {'4x400m relay'}),
#  ('Kelly Willie', {'4x400m relay'}),
#  ('Crystal Cox', {'4x400m relay'}),
#  ('Monique Henderson', {'4x400m relay'}),
#  ('Sanya Richards', {'4x400m relay'}),
#  ('Moushaumi Robinson', {'4x400m relay'}),
#  ('Deedee Trotter', {'4x400m relay'}),
#  ('Yuriy Borzakovskiy', {'800m'}),
#  ('Roman Sebrle', {'decathlon'}),
#  ('Natalya Sadova', {'discus throw'}),
#  ('Koji Murofushi', {'hammer throw'}),
#  ('Olga Kuzenkova', {'hammer throw'}),
#  ('Carolina Kluft', {'heptathlon'}),
#  ('Stefan Holm', {'high jump'}),
#  ('Elena Slesarenko', {'high jump'}),
#  ('Andreas Thorkildsen', {'javelin throw'}),
#  ('Osleidys Menendez', {'javelin throw'}),
#  ('Dwight Phillips', {'long jump'}),
#  ('Tatyana Lebedeva', {'long jump'}),
#  ('Stefano Baldini', {'marathon'}),
#  ('Mizuki Noguchi', {'marathon'}),
#  ('Timothy Mack', {'pole vault'}),
#  ('Elena Isinbaeva', {'pole vault'}),
#  ('Yuriy Bilonog', {'shot put'}),
#  ('Yumileidi Cumba', {'shot put'}),
#  ('Christian Olsson', {'triple jump'}),
#  ('Francoise Mbango etone', {'triple jump'}),
#  ('Shelly-Ann Fraser', {'100m'}),
#  ('Dawn Harper', {'100m hurdles'}),
#  ('Dayron Robles', {'110m hurdles'}),
#  ('Asbel Kipruto Kiprop', {'1500m'}),
#  ('Nancy jebet Langat', {'1500m'}),
#  ('Olga Kaniskina', {'20km race walk'}),
#  ('Valeriy Borchin', {'20km walk'}),
#  ('Brimin Kiprop Kipruto', {'3000m steeplechase'}),
#  ('Gulnara Galkina-Samitova', {'3000m steeplechase'}),
#  ('Christine Ohuruogu', {'400m'}),
#  ('Melaine Walker', {'400m hurdles'}),
#  ('Nesta Carter', {'4x100m relay'}),
#  ('Michael Frater', {'4x100m relay'}),
#  ('Asafa Powell', {'4x100m relay'}),
#  ('Yuliya Chermoshanskaya', {'4x100m relay'}),
#  ('Aleksandra Fedoriva', {'4x100m relay'}),
#  ('Yulia Gushchina', {'4x100m relay'}),
#  ('Evgeniya Polyakova', {'4x100m relay'}),
#  ('David Neville', {'4x400m relay'}),
#  ('Mary Wineberg', {'4x400m relay'}),
#  ('Alex Schwazer', {'50km walk'}),
#  ('Wilfred Bungei', {'800m'}),
#  ('Pamela Jelimo', {'800m'}),
#  ('Bryan Clay', {'decathlon'}),
#  ('Gerd Kanter', {'discus throw'}),
#  ('Stephanie Brown trafton', {'discus throw'}),
#  ('Primoz Kozmus', {'hammer throw'}),
#  ('Aksana Miankova', {'hammer throw'}),
#  ('Nataliia Dobrynska', {'heptathlon'}),
#  ('Andrey Silnov', {'high jump'}),
#  ('Tia Hellebaut', {'high jump'}),
#  ('Barbora Spotakova', {'javelin throw'}),
#  ('Irving Jahir Saladino aranda', {'long jump'}),
#  ('Maurren Higa Maggi', {'long jump'}),
#  ('Samuel Kamau Wansiru', {'marathon'}),
#  ('Constantina Tomescu', {'marathon'}),
#  ('Steve Hooker', {'pole vault'}),
#  ('Tomasz Majewski', {'shot put'}),
#  ('Valerie Vili', {'shot put'}),
#  ('Nelson Evora', {'triple jump'}),
#  ('Shelly-Ann Fraser-Pryce', {'100m'}),
#  ('Yohan Blake', {'4x100m relay'}),
#  ('Carmelita Jeter', {'4x100m relay'}),
#  ('Natalya Antyukh', {'400m hurdles'}),
#  ('DeeDee Trotter', {'4x400m relay'}),
#  ('Yuliya Zaripova', {'3000m steeplechase'}),
#  ('Ivan Ukhov', {'high jump'}),
#  ('Anna Chicherova', {'high jump'}),
#  ('Tatyana Lysenko', {'hammer throw'}),
#  ('Sergey Kirdyapkin', {'50km walk'}),
#  ('Elena Lashmanova', {'20km walk'}),
#  ('Mariya Savinova', {'800m'}),
#  ('Valerie Adams', {'shot put'}),
#  ('David Lekuta Rudisha', {'800m'}),
#  ('Olga Rypakova', {'triple jump'}),
#  ('Robert Harting', {'discus throw'}),
#  ('Krisztian Pars', {'hammer throw'}),
#  ('Kirani James', {'400m'}),
#  ('Jessica Ennis', {'heptathlon'}),
#  ('Kemar Bailey-Cole', {'4x100m relay'}),
#  ('Tiki Gelana', {'marathon'}),
#  ('Alistair Brownlee', {'triathlon (long jump / shot put / 100 yards)'}),
#  ('Greg Rutherford', {'long jump'}),
#  ('Renaud Lavillenie', {'pole vault'}),
#  ('Sally Pearson', {'100m hurdles'}),
#  ('Taoufik Makhloufi', {'1500m'}),
#  ('Ding Chen', {'20km walk'}),
#  ('Sandra Perkovic', {'discus throw'}),
#  ('Chris Brown', {'4x400m relay'}),
#  ('Michael Mathieu', {'4x400m relay'}),
#  ('Ramon Miller', {'4x400m relay'}),
#  ('Demetrius Pinder', {'4x400m relay'}),
#  ('Lauryn Williams', {'4x100m relay'}),
#  ('Jennifer Suhr', {'pole vault'}),
#  ('Ashton Eaton', {'decathlon'}),
#  ('Keshia Baker', {'4x400m relay'}),
#  ('Diamond Dixon', {'4x400m relay'}),
#  ('Brittney Reese', {'long jump'}),
#  ('Keshorn Walcott', {'javelin throw'}),
#  ('Stephen Kiprotich', {'marathon'}),
#  ('Alptekin Asli Cakir', {'1500m'}),
#  ('Nicola Spirig', {'triathlon (long jump / shot put / 100 yards)'}),
#  ('Christian Taylor', {'triple jump'}),
#  ('Bianca Knight', {'4x100m relay'}),
#  ('Aries Merritt', {'110m hurdles'}),
#  ('Jeneba Tarmoh', {'4x100m relay'}),
#  ('Tianna Madison', {'4x100m relay'}),
#  ('Francena McCorory', {'4x400m relay'}),
#  ('Tori Bowie', {'4x100m relay'}),
#  ('Vivian Jepkemoi Cheruiyot', {'5000m team'}),
#  ('Almaz Ayana', {'10miles walk (16093m)'}),
#  ('Lashawn Merritt', {'4x400m relay'}),
#  ('Morolake Akinosun', {'4x100m relay'}),
#  ('Nickel Ashmeade', {'4x100m relay'}),
#  ('Ruth Beitia', {'high jump'}),
#  ('Michelle Carter', {'shot put'}),
#  ('Matthew Centrowitz', {'1500m'}),
#  ('Kerron Clement', {'400m hurdles'}),
#  ('Kyle Clemons', {'4x400m relay'}),
#  ('Ryan Crouser', {'shot put'}),
#  ('Thiago Braz Da Silva', {'pole vault'}),
#  ('Derek Drouin', {'high jump'}),
#  ('Taylor Ellis-Watson', {'4x400m relay'}),
#  ('Phyllis Francis', {'4x400m relay'}),
#  ('English Gardner', {'4x100m relay'}),
#  ('Arman Hall', {'4x400m relay'}),
#  ('Christoph Harting', {'discus throw'}),
#  ('Natasha Hastings', {'4x400m relay'}),
#  ('Jeff Henderson', {'long jump'}),
#  ('Caterine Ibarguen', {'triple jump'}),
#  ('Ruth Jebet', {'3000m steeplechase'}),
#  ('Gwen Jorgensen', {'triathlon (long jump / shot put / 100 yards)'}),
#  ('Eliud Kipchoge', {'marathon'}),
#  ('Conseslus Kipruto', {'3000m steeplechase'}),
#  ('Faith Chepngetich Kipyegon', {'1500m'}),
#  ('Sara Kolak', {'javelin throw'}),
#  ('Hong Liu', {'20km walk'}),
#  ('Francena Mccorory', {'4x400m relay'}),
#  ('Omar Mcleod', {'110m hurdles'}),
#  ('Tony Mcquay', {'4x400m relay'}),
#  ('Shaunae Miller', {'400m'}),
#  ('Jevaughn Minzie', {'4x100m relay'}),
#  ('Dalilah Muhammad', {'400m hurdles'}),
#  ('Dilshod Nazarov', {'hammer throw'}),
#  ('Courtney Okolo', {'4x400m relay'}),
#  ('Jenna Prandini', {'4x100m relay'}),
#  ('Gil Roberts', {'4x400m relay'}),
#  ('Thomas Rohler', {'javelin throw'}),
#  ('Brianna Rollins', {'100m hurdles'}),
#  ('Caster Semenya', {'800m'}),
#  ('Ekaterini Stefanidi', {'pole vault'}),
#  ('Jemima Jelagat Sumgong', {'marathon'}),
#  ('Nafissatou Thiam', {'heptathlon'}),
#  ('Matej Toth', {'50km walk'}),
#  ('NIEKERK Wayde Van', {'400m'}),
#  ('David Verburg', {'4x400m relay'}),
#  ('Zhen Wang', {'20km walk'}),
#  ('Ariana Washington', {'4x100m relay'}),
#  ('Anita Wlodarczyk', {'hammer throw'})]

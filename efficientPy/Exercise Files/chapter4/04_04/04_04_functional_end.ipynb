# %% [markdown]
# ### Python module/package imports for this chapter

# %%
import sys, os, math, random, functools

import numpy as np

import matplotlib
import matplotlib.pyplot as pp
import matplotlib.animation as anim

# %matplotlib inline

from IPython.display import display, HTML

# %% [markdown]
# ### Code from previous videos (enhanced)

# %%
from turtle import Turtle, Terrarium

# %% [markdown]
# ## Making fractals with functional Python

# %%
def snowflake(turtle,dist,level):
    for i in range(3):
        drawkoch(turtle,dist,level)
        turtle.right(120)

def drawkoch(turtle,distance,level):
    if level == 0:
        turtle.forward(distance)
    else:
        drawkoch(turtle,distance/3,level-1)
        turtle.left(60)
        drawkoch(turtle,distance/3,level-1)
        turtle.left(-120)
        drawkoch(turtle,distance/3,level-1)
        turtle.left(60)
        drawkoch(turtle,distance/3,level-1)

# %%
with Terrarium() as t:
    drawkoch(Turtle(t),100,1)

# %%
with Terrarium() as t:
    drawkoch(Turtle(t),100,2)

# %%
with Terrarium() as t:
    drawkoch(Turtle(t),100,3)

# %%
with Terrarium(animate=True) as t:
    drawkoch(Turtle(t),100,4)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgc98cf064d87e416798920451cc654146">
#   <div class="anim-controls">
#     <input id="_anim_sliderc98cf064d87e416798920451cc654146" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animc98cf064d87e416798920451cc654146.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animc98cf064d87e416798920451cc654146.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animc98cf064d87e416798920451cc654146.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animc98cf064d87e416798920451cc654146.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animc98cf064d87e416798920451cc654146.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animc98cf064d87e416798920451cc654146.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animc98cf064d87e416798920451cc654146.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animc98cf064d87e416798920451cc654146.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animc98cf064d87e416798920451cc654146.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animc98cf064d87e416798920451cc654146.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectc98cf064d87e416798920451cc654146" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_c98cf064d87e416798920451cc654146"
#              checked>
#       <label for="_anim_radio1_c98cf064d87e416798920451cc654146">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_c98cf064d87e416798920451cc654146"
#              >
#       <label for="_anim_radio2_c98cf064d87e416798920451cc654146">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_c98cf064d87e416798920451cc654146"
#              >
#       <label for="_anim_radio3_c98cf064d87e416798920451cc654146">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgc98cf064d87e416798920451cc654146";
#     var slider_id = "_anim_sliderc98cf064d87e416798920451cc654146";
#     var loop_select_id = "_anim_loop_selectc98cf064d87e416798920451cc654146";
#     var frames = new Array(64);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjMsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+AADFEAAAF+0lEQVR4nO3bPaoTYRiG4VdJqzYRDli5BCsRN+Re\
# 3IH7cAl2gkuwPcU02imDYxGPHsHGH5g75rqahBThqe75+EjubNu2DQA5d/ceAMCvCTRAlEADRAk0\
# QJRAA0QJNECUQANECTRAlEADRAk0QJRAA0QJNECUQANECTRAlEADRAk0QJRAA0QJNECUQANECTRA\
# lEADRAk0QJRAA0QJNECUQANECTRAlEADRAk0QJRAA0QJNECUQANECTRAlEADRAk0QJRAA0QJNECU\
# QANECTRAlEADRAk0QJRAA0QJNECUQANECTRAlEADRAk0QJRAA0QJNECUQANECTRAlEADRAk0QJRA\
# A0QJNECUQANECTRAlEADRAk0QJRAA0QJNECUQANECTRAlEADRAk0QJRAA0QJNECUQANECTRAlEAD\
# RAk0QJRAA0QJNECUQANECTRAlE

# %%
with Terrarium() as t:
    t1 = Turtle(t)
    
    def flake():
        snowflake(t1,30,3)
        
    def left():
        t1.left(60)
    
    for f in [flake,left] * 6:
        f()

# %%
def over(a,b):
    return a/b

# %%
inverse = functools.partial(over,1)
half = functools.partial(over,b=2)

# %%
inverse(2)
# Out:
# 0.5

# %%
half(3)
# Out:
# 1.5

# %%
inverse
# Out:
# functools.partial(<function over at 0x114f0a040>, 1)

# %%
def F(dist):
    return functools.partial(Turtle.forward,distance=dist)

def L(ang):
    return functools.partial(Turtle.left,angle=ang)

# %%
f100 = F(100)

with Terrarium() as t:
    f100(Turtle(t))

# %%
def funckoch(steps):
    newsteps = []
    
    for step in steps:
        if step.func is Turtle.forward:
            F3 = F(step.keywords['distance']/3)
            newsteps += [F3,L(60),F3,L(-120),F3,L(60),F3]
        else:
            newsteps += [step]
            
    return newsteps

# %%
step0 = [F(100)]

# %%
funckoch(step0)
# Out:
# [functools.partial(<function Turtle.forward at 0x113ea2b80>, distance=33.333333333333336),
#  functools.partial(<function Turtle.left at 0x113ea2ca0>, angle=60),
#  functools.partial(<function Turtle.forward at 0x113ea2b80>, distance=33.333333333333336),
#  functools.partial(<function Turtle.left at 0x113ea2ca0>, angle=-120),
#  functools.partial(<function Turtle.forward at 0x113ea2b80>, distance=33.333333333333336),
#  functools.partial(<function Turtle.left at 0x113ea2ca0>, angle=60),
#  functools.partial(<function Turtle.forward at 0x113ea2b80>, distance=33.333333333333336)]

# %%
with Terrarium() as t:
    t1 = Turtle(t)
    
    for f in funckoch(funckoch(funckoch(step0))):
        f(t1)

# %%
def iterated(f,n):
    def iterf(arg):
        ret = arg
        for i in range(n):
            ret = f(ret)
        return ret
    
    return iterf

# %%
def turtle_map(self,steps):
    for step in steps:
        step(self)
        
Turtle.map = turtle_map

# %%
with Terrarium() as t:
    Turtle(t).map(iterated(funckoch,5)(step0))

# %%
triangle = [F(100),L(-120),F(100),L(-120),F(100)]

# %%
with Terrarium(animate=True,duration=2) as t:
    Turtle(t).map(iterated(funckoch,5)(triangle))
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img316753cfbb0347f88dafd2b53ad2d4c4">
#   <div class="anim-controls">
#     <input id="_anim_slider316753cfbb0347f88dafd2b53ad2d4c4" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim316753cfbb0347f88dafd2b53ad2d4c4.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim316753cfbb0347f88dafd2b53ad2d4c4.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim316753cfbb0347f88dafd2b53ad2d4c4.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim316753cfbb0347f88dafd2b53ad2d4c4.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim316753cfbb0347f88dafd2b53ad2d4c4.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim316753cfbb0347f88dafd2b53ad2d4c4.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim316753cfbb0347f88dafd2b53ad2d4c4.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim316753cfbb0347f88dafd2b53ad2d4c4.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim316753cfbb0347f88dafd2b53ad2d4c4.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim316753cfbb0347f88dafd2b53ad2d4c4.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select316753cfbb0347f88dafd2b53ad2d4c4" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_316753cfbb0347f88dafd2b53ad2d4c4"
#              checked>
#       <label for="_anim_radio1_316753cfbb0347f88dafd2b53ad2d4c4">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_316753cfbb0347f88dafd2b53ad2d4c4"
#              >
#       <label for="_anim_radio2_316753cfbb0347f88dafd2b53ad2d4c4">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_316753cfbb0347f88dafd2b53ad2d4c4"
#              >
#       <label for="_anim_radio3_316753cfbb0347f88dafd2b53ad2d4c4">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img316753cfbb0347f88dafd2b53ad2d4c4";
#     var slider_id = "_anim_slider316753cfbb0347f88dafd2b53ad2d4c4";
#     var loop_select_id = "_anim_loop_select316753cfbb0347f88dafd2b53ad2d4c4";
#     var frames = new Array(61);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjMsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+AADFEAAAG1UlEQVR4nO3ZzYqbBRSA4dMxXRQGERxKme3UheAP\
# peBddOEV9H68j+INuHTRG+hiqIM/IChSWjDQUkW6iBMXsYy1XbTqTN5xnmeTfPkScgjk5cvJpfV6\
# vR4Acna2PQAArybQAFECDRAl0ABRAg0QJdAAUQINECXQAFECDRAl0ABRAg0QJdAAUQINECXQAFEC\
# DRAl0ABRAg0QJdAAUQINECXQAFECDRAl0ABRAg0QJdAAUQINECXQAFECDRAl0ABRAg0QJdAAUQIN\
# ECXQAFECDRAl0ABRAg0QJdAAUQINECXQAFECDRAl0ABRAg0QJdAAUYttD1Dx6NGjWSx8HHBerFar\
# uXbt2rbHOFWK9KfFYjF7e3vbHgN4TcvlctsjnDorDoAogQaIEmiAKIEGiBJogCiBBogSaIAogQaI\
# EmiAKIEGiBJogCiBBogSaIAogQ

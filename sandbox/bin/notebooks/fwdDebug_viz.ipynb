# %%
from getSTDOUT import *

# %%
absolute_path_to_my_STDOUT = ''
d1 = getData( ( absolute_path_to_my_STDOUT + 'STDOUT.0000_1' ) )
d2 = getData( ( absolute_path_to_my_STDOUT + 'STDOUT.0000_2' ) )
d3 = getData( ( absolute_path_to_my_STDOUT + 'STDOUT.0000_3' ) )
d4 = getData( ( absolute_path_to_my_STDOUT + 'STDOUT.0000_4' ) )
d5 = getData( ( absolute_path_to_my_STDOUT + 'STDOUT.0000_5' ) )
d6 = getData( ( absolute_path_to_my_STDOUT + 'STDOUT.0000_6' ) )

# %%
import matplotlib.pyplot as plt

varName = 'advcfl wvel max'
plt.suptitle(varName)
plt.subplot(3,2,1)
plt.plot(d1.getVals( varName ))
plt.subplot(3,2,2)
plt.plot(d2.getVals( varName ))
plt.subplot(3,2,3)
plt.plot(d3.getVals( varName ))
plt.subplot(3,2,4)
plt.plot(d4.getVals( varName ))
plt.subplot(3,2,5)
plt.plot(d5.getVals( varName ))
plt.subplot(3,2,6)
plt.plot(d6.getVals( varName ))
plt.show()

# %%
varName = 'dynstat sst mean'
plt.suptitle(varName)
plt.subplot(3,2,1)
plt.plot(d1.getVals( varName ))
plt.subplot(3,2,2)
plt.plot(d2.getVals( varName ))
plt.subplot(3,2,3)
plt.plot(d3.getVals( varName ))
plt.subplot(3,2,4)
plt.plot(d4.getVals( varName ))
plt.subplot(3,2,5)
plt.plot(d5.getVals( varName ))
plt.subplot(3,2,6)
plt.plot(d6.getVals( varName ))

plt.show()

# %%
#print( d1.varNames ) 
from numpy import array
dvarN = array( d6.getVals( varName ) )
numb = array ( [1., 43., 4., 6., 4., 10., 10., 10., 10.])
print(type(dvarN - numb))
print(d6.getVals( varName ))
plt.plot(dvarN - numb, 'r-')
plt.show()
## Have to change list to array to do element operations using Numpy
# Out:
# <class 'numpy.ndarray'>
# [18.926929882417, 18.83694464038, 18.945907065304, 18.849849212953, 18.960849374827, 18.87075439093, 18.945593490354, 18.880325633972, 18.992661722474]

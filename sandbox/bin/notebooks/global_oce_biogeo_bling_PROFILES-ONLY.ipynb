# %%
import xarray as xr

# %%
ds=xr.open_mfdataset('/home/ivana/MITgcm/MITgcm_c68s/verification/global_oce_biogeo_bling/run_ad/sample_prof.nc')

# %%
ds2 = ds
ds2
# Out:
# <xarray.Dataset>
# Dimensions:        (iPROF: 63, iDEPTH: 25)
# Dimensions without coordinates: iPROF, iDEPTH
# Data variables: (12/21)
#     prof_descr     (iPROF) |S30 dask.array<chunksize=(63,), meta=np.ndarray>
#     prof_depth     (iDEPTH) float64 dask.array<chunksize=(25,), meta=np.ndarray>
#     prof_date      (iPROF) float64 dask.array<chunksize=(63,), meta=np.ndarray>
#     prof_YYYYMMDD  (iPROF) float64 dask.array<chunksize=(63,), meta=np.ndarray>
#     prof_HHMMSS    (iPROF) float64 dask.array<chunksize=(63,), meta=np.ndarray>
#     prof_lon       (iPROF) float64 dask.array<chunksize=(63,), meta=np.ndarray>
#     ...             ...
#     prof_Sweight   (iPROF, iDEPTH) float64 dask.array<chunksize=(63, 25), meta=np.ndarray>
#     prof_Sestim    (iPROF, iDEPTH) float64 dask.array<chunksize=(63, 25), meta=np.ndarray>
#     prof_Serr      (iPROF, iDEPTH) float64 dask.array<chunksize=(63, 25), meta=np.ndarray>
# ...

# %%
ds2 = ds2.drop({'prof_PH', 'prof_PHweight'})

# %%
ds2.to_netcdf('/home/ivana/MITgcm/MITgcm_c68s/verification/global_oce_biogeo_bling/input_ad/sample_prof_TS.nc')

# %%
ds2
# Out:
# <xarray.Dataset>
# Dimensions:        (iPROF: 63, iDEPTH: 25)
# Dimensions without coordinates: iPROF, iDEPTH
# Data variables: (12/19)
#     prof_descr     (iPROF) |S30 dask.array<chunksize=(63,), meta=np.ndarray>
#     prof_depth     (iDEPTH) float64 dask.array<chunksize=(25,), meta=np.ndarray>
#     prof_date      (iPROF) float64 dask.array<chunksize=(63,), meta=np.ndarray>
#     prof_YYYYMMDD  (iPROF) float64 dask.array<chunksize=(63,), meta=np.ndarray>
#     prof_HHMMSS    (iPROF) float64 dask.array<chunksize=(63,), meta=np.ndarray>
#     prof_lon       (iPROF) float64 dask.array<chunksize=(63,), meta=np.ndarray>
#     ...             ...
#     prof_Tflag     (iPROF, iDEPTH) float64 dask.array<chunksize=(63, 25), meta=np.ndarray>
#     prof_S         (iPROF, iDEPTH) float64 dask.array<chunksize=(63, 25), meta=np.ndarray>
#     prof_Sweight   (iPROF, iDEPTH) float64 dask.array<chunksize=(63, 25), meta=np.ndarray>
# ...

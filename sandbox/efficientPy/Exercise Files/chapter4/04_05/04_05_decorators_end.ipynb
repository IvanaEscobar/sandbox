# %% [markdown]
# ### Python module/package imports for this chapter

# %%
import sys, os, math, random, functools

import numpy as np

import matplotlib
import matplotlib.pyplot as pp
import matplotlib.animation as anim

# %matplotlib inline

from IPython.display import display, HTML

# %% [markdown]
# ### Code from previous videos (enhanced)

# %%
from turtle import Turtle, Terrarium

# %% [markdown]
# ## More functional Python

# %%
def printargs(func):
    def decorated(*args,**kwargs):
        print("Function {} called with args = {} and kwargs = {}".format(func.__name__,args,kwargs))
        
        return func(*args,**kwargs)
    
    return decorated

# %%
@printargs
def fibonacci(n):
    """Return a number in the Fibonacci sequence."""
    
    if n < 2:
        return n
    
    return fibonacci(n-1) + fibonacci(n-2)

# %%
fibonacci(5)
# Out:
# Function fibonacci called with args = (5,) and kwargs = {}
# Function fibonacci called with args = (4,) and kwargs = {}
# Function fibonacci called with args = (3,) and kwargs = {}
# Function fibonacci called with args = (2,) and kwargs = {}
# Function fibonacci called with args = (1,) and kwargs = {}
# Function fibonacci called with args = (0,) and kwargs = {}
# Function fibonacci called with args = (1,) and kwargs = {}
# Function fibonacci called with args = (2,) and kwargs = {}
# Function fibonacci called with args = (1,) and kwargs = {}
# Function fibonacci called with args = (0,) and kwargs = {}
# Function fibonacci called with args = (3,) and kwargs = {}
# Function fibonacci called with args = (2,) and kwargs = {}
# Function fibonacci called with args = (1,) and kwargs = {}
# Function fibonacci called with args = (0,) and kwargs = {}
# Function fibonacci called with args = (1,) and kwargs = {}
# 5

# %%
def fibonacci(n):
    """Return a number in the Fibonacci sequence."""
    
    if n < 2:
        return n
    
    return fibonacci(n-1) + fibonacci(n-2)

fibonacci = printargs(fibonacci)

# %%
fibonacci
# Out:
# <function __main__.printargs.<locals>.decorated(*args, **kwargs)>

# %%
help(fibonacci)
# Out:
# Help on function decorated in module __main__:
#
# decorated(*args, **kwargs)

# %%
def printargs(func):
    @functools.wraps(func)
    def decorated(*args,**kwargs):
        print("Function {} called with args = {} and kwargs = {}".format(func.__name__,args,kwargs))
        
        return func(*args,**kwargs)
    
    return decorated

@printargs
def fibonacci(n):
    """Return a number in the Fibonacci sequence."""
    
    if n < 2:
        return n
    
    return fibonacci(n-1) + fibonacci(n-2)

# %%
fibonacci
# Out:
# <function __main__.fibonacci(n)>

# %%
help(fibonacci)
# Out:
# Help on function fibonacci in module __main__:
#
# fibonacci(n)
#     Return a number in the Fibonacci sequence.

# %%
fibonacci(5)
# Out:
# Function fibonacci called with args = (5,) and kwargs = {}
# Function fibonacci called with args = (4,) and kwargs = {}
# Function fibonacci called with args = (3,) and kwargs = {}
# Function fibonacci called with args = (2,) and kwargs = {}
# Function fibonacci called with args = (1,) and kwargs = {}
# Function fibonacci called with args = (0,) and kwargs = {}
# Function fibonacci called with args = (1,) and kwargs = {}
# Function fibonacci called with args = (2,) and kwargs = {}
# Function fibonacci called with args = (1,) and kwargs = {}
# Function fibonacci called with args = (0,) and kwargs = {}
# Function fibonacci called with args = (3,) and kwargs = {}
# Function fibonacci called with args = (2,) and kwargs = {}
# Function fibonacci called with args = (1,) and kwargs = {}
# Function fibonacci called with args = (0,) and kwargs = {}
# Function fibonacci called with args = (1,) and kwargs = {}
# 5

# %%
@functools.lru_cache(maxsize=None)
@printargs
def fibonacci(n):
    """Return a number in the Fibonacci sequence."""
    
    if n < 2:
        return n
    
    return fibonacci(n-1) + fibonacci(n-2)

# %%
fibonacci(5)
# Out:
# Function fibonacci called with args = (5,) and kwargs = {}
# Function fibonacci called with args = (4,) and kwargs = {}
# Function fibonacci called with args = (3,) and kwargs = {}
# Function fibonacci called with args = (2,) and kwargs = {}
# Function fibonacci called with args = (1,) and kwargs = {}
# Function fibonacci called with args = (0,) and kwargs = {}
# 5

# %%
fibonacci(5)
# Out:
# 5

# %%
def quartercircle(t1,dist):
    for a in range(90):
        t1.forward(dist)
        t1.left(1)

with Terrarium(animate=True) as t:
    t1 = Turtle(t)
    
    for dist in [fibonacci(i) for i in range(10)]:
        quartercircle(t1,dist)
# Out:
# Function fibonacci called with args = (6,) and kwargs = {}
# Function fibonacci called with args = (7,) and kwargs = {}
# Function fibonacci called with args = (8,) and kwargs = {}
# Function fibonacci called with args = (9,) and kwargs = {}
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgcb1b2800b85c4fb9877e0a8223837d83">
#   <div class="anim-controls">
#     <input id="_anim_slidercb1b2800b85c4fb9877e0a8223837d83" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animcb1b2800b85c4fb9877e0a8223837d83.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animcb1b2800b85c4fb9877e0a8223837d83.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animcb1b2800b85c4fb9877e0a8223837d83.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animcb1b2800b85c4fb9877e0a8223837d83.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animcb1b2800b85c4fb9877e0a8223837d83.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animcb1b2800b85c4fb9877e0a8223837d83.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animcb1b2800b85c4fb9877e0a8223837d83.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animcb1b2800b85c4fb9877e0a8223837d83.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animcb1b2800b85c4fb9877e0a8223837d83.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animcb1b2800b85c4fb9877e0a8223837d83.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectcb1b2800b85c4fb9877e0a8223837d83" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_cb1b2800b85c4fb9877e0a8223837d83"
#              checked>
#       <label for="_anim_radio1_cb1b2800b85c4fb9877e0a8223837d83">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_cb1b2800b85c4fb9877e0a8223837d83"
#              >
#       <label for="_anim_radio2_cb1b2800b85c4fb9877e0a8223837d83">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_cb1b2800b85c4fb9877e0a8223837d83"
#              >
#       <label for="_anim_radio3_cb1b2800b85c4fb9877e0a8223837d83">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgcb1b2800b85c4fb9877e0a8223837d83";
#     var slider_id = "_anim_slidercb1b2800b85c4fb9877e0a8223837d83";
#     var loop_select_id = "_anim_loop_selectcb1b2800b85c4fb9877e0a8223837d83";
#     var frames = new Array(60);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjMsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+AADFEAAAFT0lEQVR4nO3YsYkDQRBFwdUxIayx+UcnY0MYmDNl\
# 3IHMeUhVEXxoeEY/1lrrACDnZ/cAAP4n0ABRAg0QJdAAUQINECXQAFECDRAl0ABRAg0QJdAAUQIN\
# ECXQAFECDRAl0ABRAg0QJdAAUQINECXQAFECDRAl0ABRAg0QJdAAUQINECXQAFECDRAl0ABRAg0Q\
# JdAAUQINECXQAFECDRAl0ABRAg0QJdAAUQINECXQAFECDRAl0ABRAg0QJdAAUQINECXQAFFj9wBe\
# ns/nMYaT0DfnPK7r2j3j46lByBjjOM9z9wx4677v3RO+ghcHQJRAA0QJNECUQANECTRAlEADRAk0\
# QJRAA0QJNECUQANECTRAlEADRAk0QJRAA0QJNECUQANECTRAlEADRAk0QJRAA0QJNECUQANECTRA\
# lEADRAk0QJRAA0QJNECUQANECT

# %%
def twice(a):
    return 2*a

for i in map(twice,range(5)):
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
for i in map(lambda a: 2*a,range(5)):
    print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
with Terrarium(animate=True) as t:
    t1 = Turtle(t)
    
    for dist in map(lambda x: x**2,map(fibonacci,range(10))):
        quartercircle(t1,dist)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgc6c2f97e2c9a4f8d9d1367566cfb09e6">
#   <div class="anim-controls">
#     <input id="_anim_sliderc6c2f97e2c9a4f8d9d1367566cfb09e6" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animc6c2f97e2c9a4f8d9d1367566cfb09e6.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="animc6c2f97e2c9a4f8d9d1367566cfb09e6.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="animc6c2f97e2c9a4f8d9d1367566cfb09e6.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="animc6c2f97e2c9a4f8d9d1367566cfb09e6.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="animc6c2f97e2c9a4f8d9d1367566cfb09e6.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="animc6c2f97e2c9a4f8d9d1367566cfb09e6.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="animc6c2f97e2c9a4f8d9d1367566cfb09e6.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="animc6c2f97e2c9a4f8d9d1367566cfb09e6.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="animc6c2f97e2c9a4f8d9d1367566cfb09e6.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="animc6c2f97e2c9a4f8d9d1367566cfb09e6.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_selectc6c2f97e2c9a4f8d9d1367566cfb09e6" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_c6c2f97e2c9a4f8d9d1367566cfb09e6"
#              checked>
#       <label for="_anim_radio1_c6c2f97e2c9a4f8d9d1367566cfb09e6">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_c6c2f97e2c9a4f8d9d1367566cfb09e6"
#              >
#       <label for="_anim_radio2_c6c2f97e2c9a4f8d9d1367566cfb09e6">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_c6c2f97e2c9a4f8d9d1367566cfb09e6"
#              >
#       <label for="_anim_radio3_c6c2f97e2c9a4f8d9d1367566cfb09e6">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgc6c2f97e2c9a4f8d9d1367566cfb09e6";
#     var slider_id = "_anim_sliderc6c2f97e2c9a4f8d9d1367566cfb09e6";
#     var loop_select_id = "_anim_loop_selectc6c2f97e2c9a4f8d9d1367566cfb09e6";
#     var frames = new Array(60);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjMsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy+AADFEAAAFT0lEQVR4nO3YsW3EMBBFQZ3BEhSo/+ouUAkE6MiR\
# nRp8OsxU8LHBC/a11loHADlfuwcA8DeBBogSaIAogQaIEmiAKIEGiBJogCiBBogSaIAogQaIEmiA\
# KIEGiBJogCiBBogSaIAogQaIEmiAKIEGiBJogCiBBogSaIAogQaIEmiAKIEGiBJogCiBBogSaIAo\
# gQaIEmiAKIEGiBJogCiBBogSaIAogQaIEmiAKIEGiBJogCiBBogSaIAogQaIEmiAKIEGiBq7B3yq\
# 9/t9jOG88GPOeVzXtXvGoyjIPxljHOd57p4BGfd9757wOF4cAFECDRAl0ABRAg0QJdAAUQINECXQ\
# AFECDRAl0ABRAg0QJdAAUQINECXQAFECDRAl0ABRAg0QJdAAUQINECXQAFECDRAl0ABRAg0QJdAA\
# UQINECXQAFECDRAl0ABRAg0QJd

# %%
with Terrarium() as t:
    t1 = Turtle(t)
    
    for dist in filter(lambda x: x % 2 == 0,map(fibonacci,range(10))):
        quartercircle(t1,dist)

# %%
functools.reduce(lambda x,y: x+y,map(fibonacci,range(10)))
# Out:
# 88

# %%
sum(map(fibonacci,range(10)))
# Out:
# 88
